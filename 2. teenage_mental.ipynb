# %% [markdown]
# # 서울시 청소년 정신건강 분석

# %%
import pandas as pd

# %%
dates = pd.date_range('20190301', periods=6)
dates
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04',
#                '2019-03-05', '2019-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495
# 2019-03-05  0.333937  0.573898  1.647656  1.143355
# 2019-03-06 -0.032623  0.153755 -0.335951  0.587945

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04',
#                '2019-03-05', '2019-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.values
# Out:
# array([[ 0.86083517,  0.77097748, -0.46986575,  1.23696423],
#        [-0.20399345,  1.16326966, -0.32017292, -0.52368918],
#        [ 0.04216699, -0.48601874,  1.61262009,  1.03718864],
#        [ 0.26383247,  0.01504606, -0.37739064, -1.35649478],
#        [ 0.33393695,  0.57389793,  1.64765576,  1.14335538],
#        [-0.03262336,  0.15375501, -0.33595087,  0.58794532]])

# %% [markdown]
# ### 2-3-3. 정렬 기능 등의 기초 활용 함수

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.210692  0.365155  0.292816  0.354212
# std    0.374237  0.589409  1.037250  1.060218
# min   -0.203993 -0.486019 -0.469866 -1.356495
# 25%   -0.013926  0.049723 -0.367031 -0.245781
# 50%    0.153000  0.363826 -0.328062  0.812567
# 75%    0.316411  0.721708  1.129422  1.116814
# max    0.860835  1.163270  1.647656  1.236964

# %%
df.sort_values(by='A')
# Out:
#                    A         B         C         D
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689
# 2019-03-06 -0.032623  0.153755 -0.335951  0.587945
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495
# 2019-03-05  0.333937  0.573898  1.647656  1.143355
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964

# %%
df.sort_values(by='A', ascending=False)
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964
# 2019-03-05  0.333937  0.573898  1.647656  1.143355
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189
# 2019-03-06 -0.032623  0.153755 -0.335951  0.587945
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689

# %%
df['A']
# Out:
# 2019-03-01    0.860835
# 2019-03-02   -0.203993
# 2019-03-03    0.042167
# 2019-03-04    0.263832
# 2019-03-05    0.333937
# 2019-03-06   -0.032623
# Freq: D, Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189

# %%
df.loc['2019-03-01']
# Out:
# A    0.860835
# B    0.770977
# C   -0.469866
# D    1.236964
# Name: 2019-03-01 00:00:00, dtype: float64

# %%
df.loc['2019-03-01', ['A']]
# Out:
# A    0.860835
# Name: 2019-03-01 00:00:00, dtype: float64

# %%
df.loc['2019-03-01', ['A', 'B']]
# Out:
# A    0.860835
# B    0.770977
# Name: 2019-03-01 00:00:00, dtype: float64

# %%
df.loc['2019-03-01':'2019-03-02', ['A', 'B']]
# Out:
#                    A         B
# 2019-03-01  0.860835  0.770977
# 2019-03-02 -0.203993  1.163270

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2019-03-01  0.860835  0.770977
# 2019-03-02 -0.203993  1.163270
# 2019-03-03  0.042167 -0.486019
# 2019-03-04  0.263832  0.015046
# 2019-03-05  0.333937  0.573898
# 2019-03-06 -0.032623  0.153755

# %%
df.iloc[0:2]
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689

# %%
df.iloc[0:2, 0:2]
# Out:
#                    A         B
# 2019-03-01  0.860835  0.770977
# 2019-03-02 -0.203993  1.163270

# %%
df.iloc[[0,1,3], 0:2]
# Out:
#                    A         B
# 2019-03-01  0.860835  0.770977
# 2019-03-02 -0.203993  1.163270
# 2019-03-04  0.263832  0.015046

# %%
df.iloc[[0,1,3]]
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495

# %%
df['A']>0
# Out:
# 2019-03-01     True
# 2019-03-02    False
# 2019-03-03     True
# 2019-03-04     True
# 2019-03-05     True
# 2019-03-06    False
# Freq: D, Name: A, dtype: bool

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495
# 2019-03-05  0.333937  0.573898  1.647656  1.143355

# %%
df>0
# Out:
#                 A      B      C      D
# 2019-03-01   True   True  False   True
# 2019-03-02  False   True  False  False
# 2019-03-03   True  False   True   True
# 2019-03-04   True   True  False  False
# 2019-03-05   True   True   True   True
# 2019-03-06  False   True  False   True

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2019-03-01  0.860835  0.770977       NaN  1.236964
# 2019-03-02       NaN  1.163270       NaN       NaN
# 2019-03-03  0.042167       NaN  1.612620  1.037189
# 2019-03-04  0.263832  0.015046       NaN       NaN
# 2019-03-05  0.333937  0.573898  1.647656  1.143355
# 2019-03-06       NaN  0.153755       NaN  0.587945

# %%
df2 = pd.DataFrame(df, columns=['A','C','D','B'])
df2
# Out:
#                    A         C         D         B
# 2019-03-01  0.860835 -0.469866  1.236964  0.770977
# 2019-03-02 -0.203993 -0.320173 -0.523689  1.163270
# 2019-03-03  0.042167  1.612620  1.037189 -0.486019
# 2019-03-04  0.263832 -0.377391 -1.356495  0.015046
# 2019-03-05  0.333937  1.647656  1.143355  0.573898
# 2019-03-06 -0.032623 -0.335951  0.587945  0.153755

# %%
df['E'] = np.nan
df
# Out:
#                    A         B         C         D   E
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964 NaN
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689 NaN
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189 NaN
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495 NaN
# 2019-03-05  0.333937  0.573898  1.647656  1.143355 NaN
# 2019-03-06 -0.032623  0.153755 -0.335951  0.587945 NaN

# %%
df.loc['2019-03-02', ['E']] = 2
df
# Out:
#                    A         B         C         D    E
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964  NaN
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689  2.0
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189  NaN
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495  NaN
# 2019-03-05  0.333937  0.573898  1.647656  1.143355  NaN
# 2019-03-06 -0.032623  0.153755 -0.335951  0.587945  NaN

# %%
df['F'] = df['A'] + df['B']
df
# Out:
#                    A         B         C         D    E         F
# 2019-03-01  0.860835  0.770977 -0.469866  1.236964  NaN  1.631813
# 2019-03-02 -0.203993  1.163270 -0.320173 -0.523689  2.0  0.959276
# 2019-03-03  0.042167 -0.486019  1.612620  1.037189  NaN -0.443852
# 2019-03-04  0.263832  0.015046 -0.377391 -1.356495  NaN  0.278879
# 2019-03-05  0.333937  0.573898  1.647656  1.143355  NaN  0.907835
# 2019-03-06 -0.032623  0.153755 -0.335951  0.587945  NaN  0.121132

# %% [markdown]
# ## 2-4. 서울시 청소년들의 스트레스 데이터를 읽어보자

# %%
pd.read_excel("./data/teenage_mental.xls")
# Out:
#      기간  구분  스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2  \
# 0    기간  구분        전체        남학생        여학생      전체       남학생       여학생
# 1  2018   구분     42.7       34.5       51.5    29.6      24.2      35.4
#
#   자살 생각률 자살 생각률.1 자살 생각률.2
# 0     전체      남학생      여학생
# 1   15.4     11.8     19.2

# %%
pd.read_excel("./data/teenage_mental.xls", header=1)
# Out:
#      기간 구분     전체   남학생   여학생  전체.1  남학생.1  여학생.1  전체.2  남학생.2  여학생.2
# 0  2018  구분  42.7  34.5  51.5  29.6   24.2   35.4  15.4   11.8   19.2

# %%
pd.read_excel("./data/teenage_mental.xls", header=1, usecols="C:K")
# Out:
#      전체   남학생   여학생  전체.1  남학생.1  여학생.1  전체.2  남학생.2  여학생.2
# 0  42.7  34.5  51.5  29.6   24.2   35.4  15.4   11.8   19.2

# %%
col_names = ['스트레스', '스트레스남학생', '스트레스여학생', '우울감경험률', 
             '우울남학생', '우울여학생','자살생각율', '자살남학생', '자살여학생']

pd.read_excel("./data/teenage_mental.xls", header=1, usecols="C:K", names=col_names)
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2

# %%
raw_data = pd.read_excel("./data/teenage_mental.xls", 
                         header=1, 
                         usecols="C:K", 
                         names=col_names)
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2

# %%
raw_data.loc[1] = 100. - raw_data.loc[0]
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 1  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %%
raw_data['응답'] = ['그렇다', '아니다']
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생   응답
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2  그렇다
# 1  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8  아니다

# %%
raw_data.set_index('응답', drop=True, inplace=True)
raw_data
# Out:
#      스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 응답
# 그렇다  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 아니다  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %% [markdown]
# ## 2-5. 데이터를 정리한 중간 코드 최종

# %%
import pandas as pd

col_names = ['스트레스', '스트레스남학생', '스트레스여학생', '우울감경험률', 
             '우울남학생', '우울여학생','자살생각율', '자살남학생', '자살여학생']

raw_data = pd.read_excel("./data/teenage_mental.xls", 
                         header=1, 
                         usecols="C:K", 
                         names=col_names)

raw_data.loc[1] = 100. - raw_data.loc[0]
raw_data['응답'] = ['그렇다','아니다']
raw_data.set_index('응답',drop=True, inplace=True)

raw_data
# Out:
#      스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 응답
# 그렇다  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 아니다  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %% [markdown]
# ## 2-6. 데이터를 시각적으로 표현하기 - matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2-6-2. matplotlib의 한글 문제

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

#f_path = "/Library/Fonts/AppleGothic.ttf"
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 2-7. 데이터를 그래프로 표현하기

# %%
raw_data
# Out:
#      스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 응답
# 그렇다  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 아니다  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %%
raw_data['스트레스'].plot.pie()

# %%
raw_data['스트레스'].plot.pie(explode=[0,0.02]);

# %%
f, ax = plt.subplots(1,3, figsize=(16,8))

raw_data['스트레스'].plot.pie(explode=[0,0.02], ax=ax[0], autopct='%1.1f%%')
ax[0].set_title('스트레스를 받은적 있다')
ax[0].set_ylabel('')

raw_data['우울감경험률'].plot.pie(explode=[0,0.02], ax=ax[1], autopct='%1.1f%%')
ax[1].set_title('우울증을 경험한적 있다')
ax[1].set_ylabel('')

raw_data['자살생각율'].plot.pie(explode=[0,0.02], ax=ax[2], autopct='%1.1f%%')
ax[2].set_title('자살을 고민한적 있다')
ax[2].set_ylabel('')

plt.show()
