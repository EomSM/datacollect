# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('../Favorites/data/netflix_titles.csv', encoding='utf-8')
df
# Out:
#      show_id     type                                        title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                         7:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
df.iloc[3:5,1:5]
# Out:
#     type title        director  \
# 3  Movie     9     Shane Acker
# 4  Movie    21  Robert Luketic
#
#                                                 cast
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...

# %%
df.iloc[0]
# Out:
# show_id                                                        s1
# type                                                      TV Show
# title                                                          3%
# director                                                      NaN
# cast            João Miguel, Bianca Comparato, Michel Gomes, R...
# country                                                    Brazil
# date_added                                        August 14, 2020
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                4 Seasons
# listed_in       International TV Shows, TV Dramas, TV Sci-Fi &...
# description     In a future where the elite inhabit an island ...
# Name: 0, dtype: object

# %%
df.pivot_table(index='rating')
# Out:
#           release_year
# rating
# G          1998.410256
# NC-17      2015.000000
# NR         2010.619048
# PG         2008.935223
# PG-13      2009.318653
# R          2010.601504
# TV-14      2013.139824
# TV-G       2015.061856
# TV-MA      2016.368495
# TV-PG      2013.133995
# TV-Y       2016.932143
# TV-Y7      2015.040590
# TV-Y7-FV   2014.833333
# UR         2002.400000

# %%
df.pivot_table(index='country')
# Out:
#                                                     release_year
# country
# Argentina                                            2016.180000
# Argentina, Brazil, France, Poland, Germany, Den...   2017.000000
# Argentina, Chile                                     2017.000000
# Argentina, Chile, Peru                               2015.000000
# Argentina, France                                    2017.000000
# Argentina, France, United States, Germany, Qatar     2017.000000
# Argentina, Italy                                     2017.000000
# Argentina, Spain                                     2012.250000
# Argentina, United States                             2019.000000
# Argentina, United States, Mexico                     2020.000000
# Argentina, Uruguay, Serbia                           2018.000000
# Argentina, Uruguay, Spain, France                    2017.000000
# Australia                                            2015.313253
# ...

# %%
df.iloc[:15,1:5]
# Out:
#        type  title              director  \
# 0   TV Show     3%                   NaN
# 1     Movie   7:19     Jorge Michel Grau
# 2     Movie  23:59          Gilbert Chan
# 3     Movie      9           Shane Acker
# 4     Movie     21        Robert Luketic
# 5   TV Show     46           Serdar Akar
# 6     Movie    122       Yasir Al Yasiri
# 7     Movie    187        Kevin Reynolds
# 8     Movie    706         Shravan Kumar
# 9     Movie   1920          Vikram Bhatt
# 10    Movie   1922          Zak Hilditch
# 11  TV Show   1983                   NaN
# 12  TV Show   1994  Diego Enrique Osorno
# 13    Movie  2,215   Nottapon Boonprakob
# 14    Movie   3022            John Suits
#
#                                                  cast
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.iloc[[1,5,7,15,20,30],1:5]
# Out:
#        type                 title           director  \
# 1     Movie                  7:19  Jorge Michel Grau
# 5   TV Show                    46        Serdar Akar
# 7     Movie                   187     Kevin Reynolds
# 15    Movie                Oct-01     Kunle Afolayan
# 20    Movie  ​​Kuch Bheege Alfaaz               Onir
# 30    Movie      #cats_the_mewvie   Michael Margolis
#
#                                                  cast
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...
# 30                                                NaN

# %%
df.iloc[[1,5,7,15,20,30],1:]
# Out:
#        type                 title           director  \
# 1     Movie                  7:19  Jorge Michel Grau
# 5   TV Show                    46        Serdar Akar
# 7     Movie                   187     Kevin Reynolds
# 15    Movie                Oct-01     Kunle Afolayan
# 20    Movie  ​​Kuch Bheege Alfaaz               Onir
# 30    Movie      #cats_the_mewvie   Michael Margolis
#
#                                                  cast        country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...          India
# 30                                                NaN         Canada
#
#            date_added  release_year rating  duration  \
# ...

# %%
df[df['director']=='David Fincher']
# Out:
#      show_id   type                            title       director  \
# 3910   s3911  Movie                             MANK  David Fincher
# 4753   s4754  Movie                       Panic Room  David Fincher
# 6396   s6397  Movie  The Girl with the Dragon Tattoo  David Fincher
# 6884   s6885  Movie               The Social Network  David Fincher
# 7774   s7775  Movie                           Zodiac  David Fincher
#
#                                                    cast  \
# 3910  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 4753  Jodie Foster, Forest Whitaker, Dwight Yoakam, ...
# 6396  Daniel Craig, Rooney Mara, Christopher Plummer...
# 6884  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 7774  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
#
#                             country         date_added  release_year rating  \
# 3910                  United States   December 4, 2020          2020      R
# ...

# %%
df[df['country']=='Mexico']
# Out:
#      show_id     type                                           title  \
# 1         s2    Movie                                            7:19
# 12       s13  TV Show                                            1994
# 292     s293    Movie                             Acapulco La vida va
# 370     s371    Movie                  Alan Saldaña: Mi vida de pobre
# 378     s379    Movie  Alex Fernández: The Best Comedian in the World
# 420     s421    Movie                   All the Freckles in the World
# 645     s646    Movie               Ayotzinapa, el paso de la tortuga
# 790     s791    Movie                           Beauties of the Night
# 800     s801  TV Show                              Becoming Champions
# 1219   s1220    Movie            Carlos Ballarta: El amor es de putos
# 1220   s1221    Movie                     Carlos Ballarta: Furia Ñera
# 1437   s1438  TV Show                                   Club of Crows
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-d03f2dad1bb5> in <module>()
# ----> 1 df_summary.iloc[40:50,[1,2,7]]
#
# NameError: name 'df_summary' is not defined
