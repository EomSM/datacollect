# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/netflix_titles.csv', encoding='utf-8')
df
# Out:
#      show_id     type                                        title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                         7:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
df.sort_values(by='title', ascending=False)
# Out:
#      show_id     type                                     title  \
# 3089   s3090    Movie                       최강전사 미니특공대 : 영웅의 탄생
# 2929   s2930    Movie                                   반드시 잡는다
# 3071   s3072  TV Show                                      마녀사냥
# 2082   s2083  TV Show                                      海的儿子
# 556     s557  TV Show                                  忍者ハットリくん
# 20       s21    Movie                      ​​Kuch Bheege Alfaaz
# 24       s25  TV Show       ​SAINT SEIYA: Knights of the Zodiac
# 23       s24    Movie                               ​Mayurakshi
# 22       s23    Movie                        ​Maj Rati ​​Keteki
# 21       s22    Movie                              ​Goli Soda 2
# 38       s39  TV Show                       แผนร้ายนายเจ้าเล่ห์
# 7700   s7701    Movie                                 يوم الدين
# 7746   s7747  TV Show                              دفعة القاهرة
# 7748   s7749    Movie                                 الف مبروك
# ...

# %%
df[6:]
# Out:
#      show_id     type                                        title  \
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# 13       s14    Movie                                        2,215
# 14       s15    Movie                                         3022
# 15       s16    Movie                                       Oct-01
# 16       s17  TV Show                                       Feb-09
# 17       s18    Movie                                       22-Jul
# 18       s19    Movie                                       15-Aug
# ...

# %%
df.iloc[6:10]
# Out:
#   show_id   type title         director  \
# 6      s7  Movie   122  Yasir Al Yasiri
# 7      s8  Movie   187   Kevin Reynolds
# 8      s9  Movie   706    Shravan Kumar
# 9     s10  Movie  1920     Vikram Bhatt
#
#                                                 cast        country  \
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 8  Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 9  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          India
#
#           date_added  release_year rating duration  \
# 6       June 1, 2020          2019  TV-MA   95 min
# 7   November 1, 2019          1997      R  119 min
# 8      April 1, 2019          2019  TV-14  118 min
# 9  December 15, 2017          2008  TV-MA  143 min
#
#                                         listed_in  \
# 6             Horror Movies, International Movies
# 7                                          Dramas
# ...

# %%
#df.loc['South Korea']

# %%
pd.read_csv('../data/netflix_titles.csv', index_col=2, encoding='utf-8')
# Out:
#                                             show_id     type  \
# title
# 3%                                               s1  TV Show
# 7:19                                             s2    Movie
# 23:59                                            s3    Movie
# 9                                                s4    Movie
# 21                                               s5    Movie
# 46                                               s6  TV Show
# 122                                              s7    Movie
# 187                                              s8    Movie
# 706                                              s9    Movie
# 1920                                            s10    Movie
# 1922                                            s11    Movie
# 1983                                            s12  TV Show
# 1994                                            s13  TV Show
# 2,215                                           s14    Movie
# ...

# %%
nf = pd.read_csv('../data/netflix_titles.csv',  index_col=2, encoding='utf-8')

# %%
nf
# Out:
#                                             show_id     type  \
# title
# 3%                                               s1  TV Show
# 7:19                                             s2    Movie
# 23:59                                            s3    Movie
# 9                                                s4    Movie
# 21                                               s5    Movie
# 46                                               s6  TV Show
# 122                                              s7    Movie
# 187                                              s8    Movie
# 706                                              s9    Movie
# 1920                                            s10    Movie
# 1922                                            s11    Movie
# 1983                                            s12  TV Show
# 1994                                            s13  TV Show
# 2,215                                           s14    Movie
# ...

# %%
nf.tail()
# Out:
#                                         show_id     type     director  \
# title
# Zozo                                      s7783    Movie  Josef Fares
# Zubaan                                    s7784    Movie  Mozez Singh
# Zulu Man in Japan                         s7785    Movie          NaN
# Zumbo's Just Desserts                     s7786  TV Show          NaN
# ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS   s7787    Movie     Sam Dunn
#
#                                                                                       cast  \
# title
# Zozo                                     Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# Zubaan                                   Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Zulu Man in Japan                                                                  Nasty C
# Zumbo's Just Desserts                                           Adriano Zumbo, Rachel Khoo
# ...

# %%
nf_piv=nf.pivot_table(index='country')
nf_piv
# Out:
#                                                     release_year
# country
# Argentina                                            2016.180000
# Argentina, Brazil, France, Poland, Germany, Den...   2017.000000
# Argentina, Chile                                     2017.000000
# Argentina, Chile, Peru                               2015.000000
# Argentina, France                                    2017.000000
# Argentina, France, United States, Germany, Qatar     2017.000000
# Argentina, Italy                                     2017.000000
# Argentina, Spain                                     2012.250000
# Argentina, United States                             2019.000000
# Argentina, United States, Mexico                     2020.000000
# Argentina, Uruguay, Serbia                           2018.000000
# Argentina, Uruguay, Spain, France                    2017.000000
# Australia                                            2015.313253
# ...

# %%
nf_piv.iloc[10]
# Out:
# release_year    2018.0
# Name: Argentina, Uruguay, Serbia, dtype: float64

# %%
nf.iloc[10]
# Out:
# show_id                                                       s11
# type                                                        Movie
# director                                             Zak Hilditch
# cast            Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# country                                             United States
# date_added                                       October 20, 2017
# release_year                                                 2017
# rating                                                      TV-MA
# duration                                                  103 min
# listed_in                                       Dramas, Thrillers
# description     A farmer pens a confession admitting to his wi...
# Name: 1922, dtype: object

# %%
nf.shape
# Out:
# (7787, 11)

# %%
nf.iloc[:11]
# Out:
#       show_id     type           director  \
# title
# 3%         s1  TV Show                NaN
# 7:19       s2    Movie  Jorge Michel Grau
# 23:59      s3    Movie       Gilbert Chan
# 9          s4    Movie        Shane Acker
# 21         s5    Movie     Robert Luketic
# 46         s6  TV Show        Serdar Akar
# 122        s7    Movie    Yasir Al Yasiri
# 187        s8    Movie     Kevin Reynolds
# 706        s9    Movie      Shravan Kumar
# 1920      s10    Movie       Vikram Bhatt
# 1922      s11    Movie       Zak Hilditch
#
#                                                     cast        country  \
# title
# 3%     João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 7:19   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 9      Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 21     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
nf.iloc[:]
# Out:
#                                             show_id     type  \
# title
# 3%                                               s1  TV Show
# 7:19                                             s2    Movie
# 23:59                                            s3    Movie
# 9                                                s4    Movie
# 21                                               s5    Movie
# 46                                               s6  TV Show
# 122                                              s7    Movie
# 187                                              s8    Movie
# 706                                              s9    Movie
# 1920                                            s10    Movie
# 1922                                            s11    Movie
# 1983                                            s12  TV Show
# 1994                                            s13  TV Show
# 2,215                                           s14    Movie
# ...

# %%
nf.iloc[[100,105], [0,6]]
# Out:
#                     show_id  release_year
# title
# 3 Idiots               s101          2009
# 300 Miles to Heaven    s106          1989

# %%
nf.iloc[[100], 0:6]
# Out:
#          show_id   type         director  \
# title
# 3 Idiots    s101  Movie  Rajkumar Hirani
#
#                                                        cast country  \
# title
# 3 Idiots  Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...   India
#
#               date_added
# title
# 3 Idiots  August 1, 2019

# %%
nf.iloc[100:105, 0:6]
# Out:
#                     show_id   type         director  \
# title
# 3 Idiots               s101  Movie  Rajkumar Hirani
# 3 Seconds Divorce      s102  Movie     Shazia Javed
# 3 Türken & ein Baby    s103  Movie      Sinan Akkuş
# 30 Days of Luxury      s104  Movie       Hani Hamdi
# 30 Minutes or Less     s105  Movie  Ruben Fleischer
#
#                                                                   cast  \
# title
# 3 Idiots             Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...
# 3 Seconds Divorce                                                  NaN
# 3 Türken & ein Baby  Kostja Ullmann, Eko Fresh, Kida Khodr Ramadan,...
# 30 Days of Luxury    Taher Farouz, Sad Al-Saghir, Ahmad Faloks, Sol...
# 30 Minutes or Less   Jesse Eisenberg, Danny McBride, Aziz Ansari, N...
#
#                            country         date_added
# title
# 3 Idiots                     India     August 1, 2019
# 3 Seconds Divorce           Canada      June 15, 2019
# ...

# %%
nf
# Out:
#                                             show_id     type  \
# title
# 3%                                               s1  TV Show
# 7:19                                             s2    Movie
# 23:59                                            s3    Movie
# 9                                                s4    Movie
# 21                                               s5    Movie
# 46                                               s6  TV Show
# 122                                              s7    Movie
# 187                                              s8    Movie
# 706                                              s9    Movie
# 1920                                            s10    Movie
# 1922                                            s11    Movie
# 1983                                            s12  TV Show
# 1994                                            s13  TV Show
# 2,215                                           s14    Movie
# ...

# %%
grouped_nf=nf.groupby(by=['release_year']).size()
#gruped=nf.groupby(by=['release_year'], as_index=True).sum
grouped_nf
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       3
# 1946       2
# 1947       1
# 1954       2
# 1955       3
# 1956       2
# 1958       3
# 1959       1
# 1960       4
# 1962       3
# 1963       2
# 1964       1
# 1965       2
# 1966       1
# 1967       5
# 1968       5
# 1969       2
# 1970       2
# 1971       5
# 1972       4
# 1973      10
# 1974       7
# 1975       6
# 1976       9
# 1977       7
# 1978       6
#         ...
# 1992      18
# 1993      22
# 1994      16
# 1995      19
# 1996      19
# 1997      30
# 1998      31
# 1999      33
# 2000      34
# 2001      36
# 2002      45
# 2003      49
# 2004      59
# 2005      73
# 2006      85
# 2007      85
# 2008     125
# 2009     137
# 2010     173
# 2011     166
# 2012     219
# 2013     267
# 2014     334
# 2015     541
# 2016     882
# 2017    1012
# 2018    1121
# 2019     996
# 2020     868
# 2021      31
# Length: 73, dtype: int64

# %%
grouped_nf.shape
# Out:
# (73,)

# %%
type(grouped_nf)
# Out:
# pandas.core.series.Series

# %%
group30=grouped_nf.tail(30)
group30
# Out:
# release_year
# 1992      18
# 1993      22
# 1994      16
# 1995      19
# 1996      19
# 1997      30
# 1998      31
# 1999      33
# 2000      34
# 2001      36
# 2002      45
# 2003      49
# 2004      59
# 2005      73
# 2006      85
# 2007      85
# 2008     125
# 2009     137
# 2010     173
# 2011     166
# 2012     219
# 2013     267
# 2014     334
# 2015     541
# 2016     882
# 2017    1012
# 2018    1121
# 2019     996
# 2020     868
# 2021      31
# dtype: int64

# %%
group30.plot.bar()

# %%
genre_nf=nf.groupby(by=['type']).size()

# %%
genre_nf
# Out:
# type
# Movie      5377
# TV Show    2410
# dtype: int64

# %%
genre_nf.plot.pie()

# %%
country_nf= nf.groupby(by=['country']).size()

# %%
country_nf
# Out:
# country
# Argentina                                                                                                                      50
# Argentina, Brazil, France, Poland, Germany, Denmark                                                                             1
# Argentina, Chile                                                                                                                1
# Argentina, Chile, Peru                                                                                                          1
# Argentina, France                                                                                                               1
# Argentina, France, United States, Germany, Qatar                                                                                1
# Argentina, Italy                                                                                                                1
# ...

# %%
top_country_nf=country_nf.sort_values(ascending=False)

# %%
top_country_nf.sort_values(ascending=True)
# Out:
# country
# France, Switzerland, Spain, United States, United Arab Emirates       1
# United Kingdom, Spain                                                 1
# United Kingdom, South Korea                                           1
# United Kingdom, South Africa, Australia, United States                1
# United Kingdom, South Africa                                          1
# United Kingdom, Singapore                                             1
# United Kingdom, Russia, United States                                 1
# United Kingdom, Poland, United States                                 1
# United Kingdom, Lithuania                                             1
# United Kingdom, Poland                                                1
# United Kingdom, Pakistan                                              1
# United Kingdom, Norway, Denmark, Germany, Sweden                      1
# United Kingdom, New Zealand                                           1
# ...

# %%
type(top_country_nf)
# Out:
# pandas.core.series.Series

# %%
top_country_nf.shape
# Out:
# (681,)

# %%
buttomup=top_country_nf.sort_values(ascending=True)
buttomup
# Out:
# country
# France, Switzerland, Spain, United States, United Arab Emirates       1
# United Kingdom, Spain                                                 1
# United Kingdom, South Korea                                           1
# United Kingdom, South Africa, Australia, United States                1
# United Kingdom, South Africa                                          1
# United Kingdom, Singapore                                             1
# United Kingdom, Russia, United States                                 1
# United Kingdom, Poland, United States                                 1
# United Kingdom, Lithuania                                             1
# United Kingdom, Poland                                                1
# United Kingdom, Pakistan                                              1
# United Kingdom, Norway, Denmark, Germany, Sweden                      1
# United Kingdom, New Zealand                                           1
# ...

# %%
top20_country=buttomup.tail(20)
top20_country
# Out:
# country
# United States, Canada              60
# Germany                            61
# United Kingdom, United States      64
# Nigeria                            70
# Indonesia                          70
# Philippines                        71
# Brazil                             72
# Taiwan                             78
# Australia                          83
# Turkey                            100
# Mexico                            100
# Egypt                             101
# France                            115
# Spain                             134
# Canada                            177
# South Korea                       183
# Japan                             226
# United Kingdom                    397
# India                             923
# United States                    2555
# dtype: int64

# %%
top20_country.plot.pie()

# %%
plt.pie(top20_country)
plt.axis('equal')
plt.pie(top20_country, autopct="%0.1f%%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-222-9cca0309b0e6> in <module>()
#       1 plt.pie(top20_country)
#       2 plt.axis('equal')
# ----> 3 plt.pie(top20_country, labels, autopct="%0.1f%%")
#
# NameError: name 'labels' is not defined

# %%
top10_country=buttomup.tail(10)
top10_country
# Out:
# country
# Mexico             100
# Egypt              101
# France             115
# Spain              134
# Canada             177
# South Korea        183
# Japan              226
# United Kingdom     397
# India              923
# United States     2555
# dtype: int64

# %%
top10_country.plot.pie(autopct="%0.1f%%")

# %%
rating= nf.groupby(by=['rating']).size()

# %%
rating.plot.pie(autopct="%0.1f%%")

# %%
rating.plot.bar()

# %%
nf.scatterplot(data=nf, x='country', y='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-237-baaa233fcb91> in <module>()
# ----> 1 rating.distplot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distplot'
