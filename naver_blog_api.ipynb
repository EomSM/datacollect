# %%
import urllib.request

# %%
client_id ="sOiJUp7sd7dBiZpgADzZ"
client_secret = "xSmJkjTmIU"

# %%
encText = urllib.parse.quote("스프링")
url = "https://openapi.naver.com/v1/search/blog.json?query=" + encText
url
# Out:
# 'https://openapi.naver.com/v1/search/blog.json?query=%EC%8A%A4%ED%94%84%EB%A7%81'

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

# %%
response = urllib.request.urlopen(request)
response.getcode()
# Out:
# 200

# %%
for n in [1,2,3]:
    print(n)
# Out:
# 1
# 2
# 3

# %%
[n-2 for n in [1,2,3]]
# Out:
# [-1, 0, 1]

# %%
[n**2 for n in range(1,6)]
# Out:
# [1, 4, 9, 16, 25]

# %%
def get_square(n):
    return n**2;

# %%
[get_square(n) for n in range(1,6)]
# Out:
# [1, 4, 9, 16, 25]

# %%
def create_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    return base + node + param_query + param_start + param_disp

# %%
create_url("book", "스프링", 1,3)
# Out:
# 'https://openapi.naver.com/v1/search/book.json?query=%EC%8A%A4%ED%94%84%EB%A7%81&start=1&display=3'

# %%
client_id ="sOiJUp7sd7dBiZpgADzZ"
client_secret = "xSmJkjTmIU"

url = create_url("book", "스프링", 1,100)

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
# response.getcode()
# response.read()
content = response.read().decode('utf-8')
content
# Out:
# '{\n"lastBuildDate": "Sun, 25 Apr 2021 23:36:03 +0900",\n"total": 5100,\n"start": 1,\n"display": 100,\n"items": [\n{\n"title": "올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=17193966",\n"image": "https://bookthumb-phinf.pstatic.net/cover/171/939/17193966.jpg?type=m1&udate=20210324",\n"author": "올리버 샨 그랜트",\n"price": "18500",\n"discount": "16650",\n"publisher": "비에이블",\n"pubdate": "20201119",\n"isbn": "1190931184 9791190931182",\n"description": "하루 3분, 미국인 선생님과 함께하는 매일 영어 습관\\n“원어민 발음에 귀가 열리고, 요즘 영어로 더 유창하게 말하게 된다!”\\n외국어 분야 베스트셀러 저자인 올리버쌤이 하루 한 문장씩 1년간 365개 표현을 익힐 수 있는 영어회화 일력을 출간했다. 미국인이 아니면 가르쳐줄 수 없는 원어민들의 생활 속 표현을... "\n\n},\n{\n"title": "구슬쥬의 시크릿 내신노트 (<b>스프링</b>)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=18122051",\n"image": "https://bookthumb-phinf.pstatic.net/cover/181/220/18122051.jpg?type=m1&udate=20210322",\n"author": "구슬쥬",\n"price": "15000",\n"discount": "13500",\n"publisher": "메리포핀스",\n"pubdate": "20210228",\n"isbn": "119642733X 9791196427337",\n"description": "그래서 탄생했다. 구슬쥬의 시크릿 내신노트!5만 구독자를 바라보는 공부 유튜버, 구슬쥬가 가장 많이 듣는 말은 “나만 알고 싶은 언니!”라는 말이다. 취미 삼아 시작한 유튜브이지만, 그녀는 영상을 본 사람이라면 ‘나만 알고 싶다’는 생각이 들 정도의 실질적인 ‘공부 꿀팁’만 담아서 영상을 만들어왔고... "\n\n},\n{\n"title": "2021 전한길 한국사 포켓 암기노트 (<b>스프링</b>) (공무원 시험 대비)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=16749210",\n"image": "https://bookthumb-phinf.pstatic.net/cover/167/492/16749210.jpg?type=m1&udate=20210324",\n"author": "전한길",\n"price": "8500",\n"discount": "",\n"publisher": "전한길한국사",\n"pubdate": "20201010",\n"isbn": "1197133550 9791197133558",\n"description": "공무원 시험의 시작부터 마무리할 때까지 활용이 가능하며, 수험생들이 시간과 장소에 상관없이 수시로 학습할 수 있도록 휴대하기 간편한 사이즈의 <b>스프링</b> 제본으로 제작되었다. \\n\\n본서는 중요 키워드를 빈칸 처리하였으며, 사진 및 사료도 풍부하게 수록하였다. 또한, 기출 지문으로 구성한 OX문제로 학습한... "\n\n},\n{\n"title": "하루 한 장 365 인문학 달력 (<b>스프링</b>) (매일 한 뼘씩 아이 마음이 자라는)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=17546229",\n"image": "https://bookthumb-phinf.pstatic.net/cover/175/462/17546229.jpg?type=m1&udate=20210330",\n"author": "김종원",\n"price": "16000",\n"discount": "14400",\n"publisher": "청림Life",\n"pubdate": "20201209",\n"isbn": "1188700723 9791188700721",\n"description": "15만 부모의 인문교육 멘토, 김종원 작가의 365일 인문학 달력\\n매일 한 뼘씩 아이 내면의 힘을 단단하게 키워줄\\n인생 문장과 함께 하루를 시작하세요!15만 부모의 찬사를 받은 『아이를 위한 하루 한 줄 인문학』 시리즈와 『부모 인문학 수업』 속 인생 문장을 엄선해 12가지 테마로 엮은 365일 만년 달력.... "\n\n},\n{\n"title": "2021 에듀윌 공인중개사 부동산세법 체계도 (<b>스프링</b>) (빠른 합격을 위한 세법 압출 끝판왕!, 세법 암기 카드 제공)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=17853855",\n"image": "https://bookthumb-phinf.pstatic.net/cover/178/538/17853855.jpg?type=m1&udate=20210204",\n"author": "신성룡",\n"price": "12000",\n"discount": "10800",\n"publisher": "에듀윌",\n"pubdate": "20210201",\n"isbn": "113600906X 9791136009067",\n"description": "방대한 부동산세법 핵심을 체계도로 압축 정리!\\n빠른 합격을 위한 세법 압축 끝판왕!\\n체계를 알아야 합격이 보인다!부동산세법은 내용이 방대하고 암기 내용이 각 세목별로 비슷하기 때문에 수험생들이 학습하기 까다로운 과목입니다. 하지만 체계를 통하여 접근하면 세법은 더 이상 어려운 과목이 아닙니다.... "\n\n},\n{\n"title": "하루 한 장 초등필수영단어 + 사이트 워드 따라쓰기 (<b>스프링</b>) (QR코드 및 MP3음원제공)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=16684445",\n"image": "https://bookthumb-phinf.pstatic.net/cover/166/844/16684445.jpg?type=m1&udate=20200920",\n"author": "이문필",\n"price": "12500",\n"discount": "11250",\n"publisher": "베이직북스",\n"pubdate": "20200921",\n"isbn": "1163400467 9791163400462",\n"description": "분류하여 95일 동안 950개의 단어를 체계적으로 학습할 수 있도록 구성하였습니다.  \\n-하루에 10단어 학습(<b>스프링</b>북으로 되어 있어 한 장씩 떼어낼 수 있어요)\\n-5일분의 학습이 끝날 때마다 재미있는 퀴즈로 복습\\n-바로바로 원어민의 음성을 들을 수 있는 큐알코드 수록\\n-영어 발음 기호와 한글 발음 동시 수록"\n\n},\n{\n"title": "초등교과 어휘왕 가로세로 낱말퍼즐(고급)(<b>스프링</b>)",\n"link": "http://book.naver.com/bookdb/book_detail.php?bid=18830241",\n"image": "https://bookthumb-phinf.pstatic.net/cover/188/302/18830241.jpg?type=m1&udate=20210327",\n"author": "베이직콘텐츠연구소",\n"price": "10800",\n"discount": "8640",\n"publisher": "키즈프렌즈",\n"pubdate": "20210405",\n"isbn": "9565330088 8809565330087",\n"description": "초등 어휘 ...

# %%
import json

# %%
result = json.loads(content)
result
# Out:
# {'lastBuildDate': 'Sun, 25 Apr 2021 23:36:03 +0900',
#  'total': 5100,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17193966',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/171/939/17193966.jpg?type=m1&udate=20210324',
#    'author': '올리버 샨 그랜트',
#    'price': '18500',
#    'discount': '16650',
#    'publisher': '비에이블',
#    'pubdate': '20201119',
#    'isbn': '1190931184 9791190931182',
#    'description': '하루 3분, 미국인 선생님과 함께하는 매일 영어 습관\n“원어민 발음에 귀가 열리고, 요즘 영어로 더 유창하게 말하게 된다!”\n외국어 분야 베스트셀러 저자인 올리버쌤이 하루 한 문장씩 1년간 365개 표현을 익힐 수 있는 영어회화 일력을 출간했다. 미국인이 아니면 가르쳐줄 수 없는 원어민들의 생활 속 표현을... '},
#   {'title': '구슬쥬의 시크릿 내신노트 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18122051',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/181/220/18122051.jpg?type=m1&udate=20210322',
#    'author': '구슬쥬',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '메리포핀스',
#    'pubdate': '20210228',
#    'isbn': '119642733X 9791196427337',
#    'description': '그래서 탄생했다. 구슬쥬의 시크릿 내신노트!5만 구독자를 바라보는 공부 유튜버, 구슬쥬가 가장 많이 듣는 말은 “나만 알고 싶은 언니!”라는 말이다. 취미 삼아 시작한 유튜브이지만, 그녀는 영상을 본 사람이라면 ‘나만 알고 싶다’는 생각이 들 정도의 실질적인 ‘공부 꿀팁’만 담아서 영상을 만들어왔고... '},
#   {'title': '2021 전한길 한국사 포켓 암기노트 (<b>스프링</b>) (공무원 시험 대비)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16749210',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/167/492/16749210.jpg?type=m1&udate=20210324',
#    'author': '전한길',
#    'price': '8500',
#    'discount': '',
#    'publisher': '전한길한국사',
#    'pubdate': '20201010',
#    'isbn': '1197133550 9791197133558',
#    'description': '공무원 시험의 시작부터 마무리할 때까지 활용이 가능하며, 수험생들이 시간과 장소에 상관없이 수시로 학습할 수 있도록 휴대하기 간편한 사이즈의 <b>스프링</b> 제본으로 제작되었다. \n\n본서는 중요 키워드를 빈칸 처리하였으며, 사진 및 사료도 풍부하게 수록하였다. 또한, 기출 지문으로 구성한 OX문제로 학습한... '},
#   {'title': '하루 한 장 365 인문학 달력 (<b>스프링</b>) (매일 한 뼘씩 아이 마음이 자라는)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17546229',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/175/462/17546229.jpg?type=m1&udate=20210330',
#    'author': '김종원',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '청림Life',
#    'pubdate': '20201209',
#    'isbn': '1188700723 9791188700721',
#    'description': '15만 부모의 인문교육 멘토, 김종원 작가의 365일 인문학 달력\n매일 한 뼘씩 아이 내면의 힘을 단단하게 키워줄\n인생 문장과 함께 하루를 시작하세요!15만 부모의 찬사를 받은 『아이를 위한 하루 한 줄 인문학』 시리즈와 『부모 인문학 수업』 속 인생 문장을 엄선해 12가지 테마로 엮은 365일 만년 달력.... '},
#   {'title': '2021 에듀윌 공인중개사 부동산세법 체계도 (<b>스프링</b>) (빠른 합격을 위한 세법 압출 끝판왕!, 세법 암기 카드 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17853855',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/178/538/17853855.jpg?type=m1&udate=20210204',
#    'author': '신성룡',
#    'price': '12000',
#    'discount': '10800',
#    'publisher': '에듀윌',
#    'pubdate': '20210201',
#    'isbn': '113600906X 9791136009067',
#    'description': '방대한 부동산세법 핵심을 체계도로 압축 정리!\n빠른 합격을 위한 세법 압축 끝판왕!\n체계를 알아야 합격이 보인다!부동산세법은 내용이 방대하고 암기 내용이 각 세목별로 비슷하기 때문에 수험생들이 학습하기 까다로운 과목입니다. 하지만 체계를 통하여 접근하면 세법은 더 이상 어려운 과목이 아닙니다.... '},
#   {'title': '하루 한 장 초등필수영단어 + 사이트 워드 따라쓰기 (<b>스프링</b>) (QR코드 및 MP3음원제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16684445',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/166/844/16684445.jpg?type=m1&udate=20200920',
#    'author': '이문필',
#    'price': '12500',
#    'discount': '11250',
#    'publisher': '베이직북스',
#    'pubdate': '20200921',
#    'isbn': '1163400467 9791163400462',
#    'description': '분류하여 95일 동안 950개의 단어를 체계적으로 학습할 수 있도록 구성하였습니다.  \n-하루에 10단어 학습(<b>스프링</b>북으로 되어 있어 한 장씩 떼어낼 수 있어요)\n-5일분의 학습이 끝날 때마다 재미있는 퀴즈로 복습\n-바로바로 원어민의 음성을 들을 수 있는 큐알코드 수록\n-영어 발음 기호와 한글 발음 동시 수록'},
#   {'title': '초등교과 어휘왕 가로세로 낱말퍼즐(고급)(<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18830241',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/188/302/18830241.jpg?type=m1&udate=20210327',
#    'author': '베이직콘텐츠연구소',
#    'price': '10800',
#    'discount': '8640',
#    'publisher': '키즈프렌즈',
#    'pubdate': '20210405',
#    'isbn': '9565330088 8809565330087',
#    'description': '초등 어휘력이 공부력이다!\n초등교과서 필수 어휘 4천여 개 수록《초등교과 어휘왕 가로세로 낱말 퍼즐》은 초등학교 전 과목 교과서와 일상생활에서 초등학생들이 꼭 알아야 할 낱말들을 골라 퍼즐로 만들었어요. 모르는 단어도 앞뒤 단어와 예시문을 통해 낱말을 유추하고 놀이하듯 빈칸을 채우면서 뜻을 알게... '},
#   {'title': '초등교과 어휘왕 가로세로 낱말퍼즐 : 중급 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17982776',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/179/827/17982776.jpg?type=m1&udate=20210225',
#    'author': '베이직콘텐츠연구소',
#    'price': '10800',
#    'discount': '8640',
#    'publisher': '키즈프렌즈',
#    'pubdate': '20210225',
#    'isbn': '956533007X 8809565330070',
#    'description': '초등 어휘력이 공부력이다!\n초등교과서 필수 어휘 4천여 개 수록《초등교과 어휘왕 가로세로 낱말 퍼즐》은 초등학교 전 과목 교과서와 일상생활에서 초등학생들이 꼭 알아야 할 낱말들을 골라 퍼즐로 만들었어요. 모르는 단어도 앞뒤 단어와 예시문을 통해 낱말을 유추하고 놀이하듯 빈칸을 채우면서 뜻을 알게... '},
#   {'title': '[개정판] 피아노로 연주하는 디즈니 OST 베스트 Original Ver. (<b>스프링</b>) (체르니 30 이상 난이도)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16270696',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/706/16270696.jpg?type=m1&udate=20200222',
#    'author': '정유리|콘텐츠기획개발부',
#    'price': '18000',
#    'discount': '16200',
#    'publisher': '삼호뮤직',
#    'pubdate': '20200228',
#    'isbn': '8932637717 9788932637716',
#    'description': "꿈과 환상을 전해줄 디즈니의 선물!\n피아노로 연주하는 디즈니 OST 베스트!디즈니만의 색으로 남녀노소, 동서고금을 막론하고 감동을 전해주는 디즈니의 음악! 『피아노로 연주하는 디즈니 OST 베스트 ORIGINAL VER.』 개정판. 피아노로 연주하는 디즈니 OST 베스트'는 그런 디즈니 작품들의 오리지널 사운드... "},
#   {'title': '피지컬갤러리의 하루 5분 내 몸 관리법(<b>스프링</b>) (대한민국 1등 건강 유튜브 200만 채널)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16491909',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/919/16491909.jpg?type=m1&udate=20201007',
#    'author': '라이프에이드',
#    'price': '19800',
#    'discount': '17820',
#    'publisher': '시간과공간사',
#    'pubdate': '20200910',
#    'isbn': '119081806X 9791190818063',
#    'description': '독서대 기능이 있는 특허 받은 제본은 특히 자랑할 만하다. 책상에 세워두고 멀찍이 앉아도 눈에 들어오도록 활자를 키웠다. 책장이 쉽게 넘어가는 <b>스프링</b>제본을 추가했다. 고개를 숙일 필요가 없고 멀리 떨어져 볼 수 있어서 눈 건강, 척추 건강에도 좋은 책이다.'},
#   {'title': '<b>스프링</b>북 교과서 가로세로 낱말퍼즐 : 초급 (<b>스프링</b>) (초등학생 필수 어휘 총출동!)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16363381',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/633/16363381.jpg?type=m1&udate=20210301',
#    'author': '김수웅',
#    'price': '9800',
#    'discount': '8820',
#    'publisher': '시간과공간사',
#    'pubdate': '20200630',
#    'isbn': '1190818019 9791190818018',
#    'description': '시리즈 모두 고급스러운 <b>스프링</b>제본으로 아이들이 쉽게 책장을 넘기고 필기할 수 있도록 도왔습니다. 모든 공부의 기본은 어휘력이라는 말처럼, 우리 아이들이 이 책을 놀이 삼아 풀면서 어휘력을 향상시키고 탄탄한 학업의 기초를 쌓기를 바라는 저자의 진심이 온전히 전해지기를 바랍니다.'},
#   {'title': '피아노로 연주하는 디즈니 OST 베스트 Easy Ver.(개정판)(<b>스프링</b>) (체르니 100~30 난이도)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16270812',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/708/16270812.jpg?type=m1&udate=20200310',
#    'author': '정유리|콘텐츠기획개발부',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '삼호뮤직',
#    'pubdate': '20200228',
#    'isbn': '8932637709 9788932637709',
#    'description': "꿈과 환상을 전해줄 디즈니의 선물!\n피아노로 연주하는 디즈니 OST 베스트!디즈니만의 색으로 남녀노소, 동서고금을 막론하고 감동을 전해주는 디즈니의 음악! '피아노로 연주하는 디즈니 OST 베스트[개정판]'은 그런 디즈니 작품들의 오리지널 사운드 트랙들을 모아, 피아노 솔로 연주곡으로 쉽게 편곡하여... "},
#   {'title': '보카바이블 4.0 데스크북(+미니단어장)(<b>스프링</b>) (공무원, 편입, 토플, 텝스, SAT, GRE 대비서)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16122710',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/161/227/16122710.jpg?type=m1&udate=20200129',
#    'author': '허민',
#    'price': '17500',
#    'discount': '15750',
#    'publisher': '스텝업',
#    'pubdate': '20200108',
#    'isbn': '8994553118 9788994553115',
#    'description': '보카바이블 4.0 데스크북(+미니단어장)은 영어단어를 좀 더 자주 볼 수 있도록 하기 위해 공부하는 책상 위에 올려두고 수시로 보는 캘린더형식으로 만들어진 영어단어장입니다. 또한 점심시간이나 대중교통으로 이동하는 시간에 휴대하면서 짬짬이 볼 수 있도록 미니단어장도 함께 제공됩니다. 독서실 책상위엔... '},
#   {'title': '<b>스프링</b>북 교과서 가로세로 낱말퍼즐 중급(<b>스프링</b>) (초등학생 필수 어휘 총출동)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16404759',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/047/16404759.jpg?type=m1&udate=20200707',
#    'author': '김수웅',
#    'price': '9800',
#    'discount': '8820',
#    'publisher': '시간과공간사',
#    'pubdate': '20200730',
#    'isbn': '1190818043 9791190818049',
#    'description': '시리즈 모두 고급스러운 <b>스프링</b>제본으로 아이들이 쉽게 책장을 넘기고 필기할 수 있도록 도왔습니다. 모든 공부의 기본은 어휘력이라는 말처럼, 우리 아이들이 이 책을 놀이 삼아 풀면서 어휘력을 향상시키고 탄탄한 학업의 기초를 쌓기를 바라는 저자의 진심이 온전히 전해지기를 바랍니다.'},
#   {'title': '<b>스프링</b> 부트와 AWS로 혼자 구현하는 웹 서비스 (인텔리제이, JPA, JUnit 테스트, 그레이들, 소셜 로그인, AWS 인프라로 무중단 배포까지)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15871738',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/158/717/15871738.jpg?type=m1&udate=20191128',
#    'author': '이동욱',
#    'price': '22000',
#    'discount': '19800',
#    'publisher': '프리렉',
#    'pubdate': '20191129',
#    'isbn': '8965402603 9788965402602',
#    'description': '경험이 실력이 되는 순간!이 책은 제목 그대로 <b>스프링</b> 부트와 AWS로 웹 서비스를 구현합니다. JPA와 JUNIT 테스트, 그레이들, 머스테치, <b>스프링</b> 시큐리티를... 이렇게 점진적으로 <b>스프링</b> 부트 프로젝트를 개선해서 배포 자동화하고 무중단 배포까지 경험합니다. 실무 현장에서의 노하우와 테스트 방법, 객체지향... '},
#   {'title': '혜민 스님의 따뜻한 응원(2020)(<b>스프링</b>) (365일 마음 달력)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15910263',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/159/102/15910263.jpg?type=m1&udate=20200123',
#    'author': '혜민',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '수오서재',
#    'pubdate': '20191126',
#    'isbn': '1190382067 9791190382069',
#    'description': '힘이 되고 위안이 되는, 혜민 스님 잠언을 365일 만나세요\n두고두고 보는 혜민 스님 만년 달력!많은 이에게 용기와 지혜, 고요의 시간을 선물한 혜민 스님의 잠언을 엮은 365일 달력. SNS 3백만 팔로워들의 아침을 열어주는 〈혜민 스님의 따뜻한 응원〉을 책상이나 머리맡에 두고 한 장 한 장 넘기며 하루를... '},
#   {'title': '스도쿠x로직아트(초급/중급)(<b>스프링</b>) (뇌과학이 입증한 최고의 두뇌 게임!)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16375653',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/756/16375653.jpg?type=m1&udate=20200626',
#    'author': '브레이니 퍼즐 랩',
#    'price': '8800',
#    'discount': '7920',
#    'publisher': '시간과공간사',
#    'pubdate': '20200710',
#    'isbn': '1190818035 9791190818032',
#    'description': '●스도쿠와 로직아트 둘 다 수학적 원리에 기반해 만들어졌다. 연령, 학력, 성별 상관없이 재밌게 풀다 보면 논리력, 수리력, 추리력이 저절로 발달하게 된다.\n●<b>스프링</b>이 겉면에 드러나지 않는 고급스러운 <b>스프링</b>제본으로 사용성과 품질을 높였다. \n●고급/고수편도 곧 출시될 예정이다.'},
#   {'title': '네이티브만 아는 진짜 영어 100(<b>스프링</b>) (수많은 구독자가 열광하는 문법 밖 영어회화)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16328832',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/288/16328832.jpg?type=m1&udate=20210204',
#    'author': '구슬쌤',
#    'price': '13500',
#    'discount': '12150',
#    'publisher': '시원스쿨닷컴',
#    'pubdate': '20200416',
#    'isbn': '1161503358 9791161503356',
#    'description': '문법상 틀린 건 아닌데 어색했던 영어,\n영어 교육 유튜버이자 영어회화 전문 강사 ‘구슬쌤’이 자연스럽게 만들어 줍니다!“점심 먹자.”고 할 땐 EAT보단 GRAB!\n‘알려 달라’고 할 땐 TELL ME보단 LET ME KNOW!\n감기 걸려 병원에 갈 땐 HOSPITAL보단 CLINIC!\n\n문법으로 해결되지 않는 영어 자연스럽게 말하는... '},
#   {'title': '2021 이공자 ITQ 파워포인트 2016 (<b>스프링</b>) (최신 자동채점프로그램 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18125411',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/181/254/18125411.jpg?type=m1&udate=20210402',
#    'author': 'KIE 기획연구실',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '아소미디어(아카데미소프트)',
#    'pubdate': '20210225',
#    'isbn': '8984550205 9788984550209',
#    'description': '- 2020년 7월 정기시험부터 새롭게 변경된 시험유형을 모두 반영한 최신교재!!\n- 기출 예상문제 완벽대비!!\n- 최신 자동채점프로그램 무료 제공!!'},
#   {'title': '뷰티 일러스트레이션 워크북 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18866733',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/188/667/18866733.jpg?type=m1&udate=20210405',
#    'author': '오수나|김유경|박혜원|정혜영|조애라',
#    'price': '23000',
#    'discount': '22310',
#    'publisher': '구민사',
#    'pubdate': '20210330',
#    'isbn': '1158139136 9791158139131',
#    'description': 'How to illustration! 뷰티 일러스트레이션 워크북은 뷰티 전공자들의 뷰티 일러스트레이션을 위한 입문서로 기초 드로잉 과정을 중심으로 집필되었습니다. 많은 것들이 디지털화 되어가고 있고 일러스트의 방식도 다양화되어 가고 있으나 뷰티 일러스트레이션 워크북은 모든 작업이 드로잉에 기반하고 있음을 잊지... '},
#   {'title': '우리들의 예쁜 손글씨(손글씨 따라쓰기 교본 1)(<b>스프링</b>) (일기체)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16240534',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/405/16240534.jpg?type=m1&udate=20200207',
#    'author': '김정은|김지향',
#    'price': '12000',
#    'discount': '10800',
#    'publisher': '북코디',
#    'pubdate': '20200205',
#    'isbn': '1195994958 9791195994953',
#    'description': '일상의 기록을 위해 ‘일기체’를 추천합니다우리는 매일매일 기록을 하면서 살고 있습니다.\n\n누군가에게 짧은 메모를 남기고,\n사야 하거나 사고 싶은 것들을 써 두고,\n나의 마음을 전하고 싶어 또박또박 손편지를 쓰고,\n하루를 정리하면서 나에 대한 얘기로 일기를 써 내려가는 등\n하루종일 우리는 무엇인가를... '},
#   {'title': '<b>스프링</b>북 어린이 스도쿠 2 (고급.고수)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14103819',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/141/038/14103819.jpg?type=m1&udate=20181110',
#    'author': '브레이니 퍼즐 랩',
#    'price': '7700',
#    'discount': '6930',
#    'publisher': '시간과공간사',
#    'pubdate': '20181101',
#    'isbn': '8971422645 9788971422649',
#    'description': '어린이의 눈높이에 맞춘 <b>스프링</b>북 어린이 스도쿠!하나씩 풀다 보면 논리력 / 집중력 / 추리력 강화!... <b>스프링</b> 제본이라 완전하게 펼쳐지고 반으로 접을 수도 있습니다.? 둥근 모서리는 손을 보호해줘요~4X4... 편하게 <b>스프링</b> 제본으로 만들었습니다. 둥글게 라운드 처리된 모서리는 아이들의 손을 보호해줘요... '},
#   {'title': '<b>스프링</b>북 어린이 스도쿠 1 (초급.중급)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14103818',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/141/038/14103818.jpg?type=m1&udate=20181031',
#    'author': '브레이니 퍼즐 랩',
#    'price': '7700',
#    'discount': '6930',
#    'publisher': '시간과공간사',
#    'pubdate': '20181101',
#    'isbn': '8971422637 9788971422632',
#    'description': '어린이의 눈높이에 맞춘 <b>스프링</b>북 어린이 스도쿠!하나씩 풀다 보면 논리력 / 집중력 / 추리력 강화!... <b>스프링</b> 제본이라 완전하게 펼쳐지고 반으로 접을 수도 있습니다.? 둥근 모서리는 손을 보호해줘요~4X4... 편하게 <b>스프링</b> 제본으로 만들었습니다. 둥글게 라운드 처리된 모서리는 아이들의 손을 보호해줘요... '},
#   {'title': '신비아파트 하루 한 장 : 속담 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18215363',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/182/153/18215363.jpg?type=m1&udate=20210409',
#    'author': '서울문화사 편집부',
#    'price': '18000',
#    'discount': '14400',
#    'publisher': '서울문화사',
#    'pubdate': '20210330',
#    'isbn': '9170011249 8809170011241',
#    'description': '신비아파트 친구들과 함께\n신나게 배우고 써 보는 우리 속담 100!〈신비아파트 속담 사전〉을 쓰기 책으로 재구성!\n〈신비아파트 하루 한 장 속담〉은 〈신비아파트 고스트볼X의 탄생 속담 사전〉에서 다양한 우리 속담 중에서 100가지를 골라, 쓰기 책으로 구성하였습니다. 이 책에서는 속담 내용은 기존의... '},
#   {'title': '읽기유창성 및 읽기이해 프로그램 교사용 (<b>스프링</b>) (학령기 아동을 위한)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18898177',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/188/981/18898177.jpg?type=m1&udate=20210409',
#    'author': '김애화|김의정',
#    'price': '25000',
#    'discount': '22500',
#    'publisher': '학지사',
#    'pubdate': '20210330',
#    'isbn': '8999723771 9788999723773',
#    'description': ''},
#   {'title': '나 혼자 기타 친다 비기너 (<b>스프링</b>) (정완의 기타 독학)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18214730',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/182/147/18214730.jpg?type=m1&udate=20210316',
#    'author': '최정완',
#    'price': '17000',
#    'discount': '15300',
#    'publisher': '삼호ETM',
#    'pubdate': '20210320',
#    'isbn': '8967212569 9788967212568',
#    'description': '『나 혼자 기타 친다 비기너』는 기타를 독학으로 처음 시작하는 사람들을 위하여 상세하고 체계적인 커리큘럼으로 이루어져 있는 친절한 독학서입니다. 기타 필수곡이자 기타로 가장 치고 싶은 최고의 명곡을 다수 수록하였고, Q&A와 각 챕터별 연습 문제 풀이까지 다양한 내용으로 구성되어 있습니다.... '},
#   {'title': '코드로 배우는 <b>스프링</b> 부트 웹 프로젝트 (현업 개발을 위한 단계별 실습서(동영상 강의 제공))',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17597624',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/175/976/17597624.jpg?type=m1&udate=20201223',
#    'author': '구멍가게 코딩단',
#    'price': '34000',
#    'discount': '30600',
#    'publisher': '남가람북스',
#    'pubdate': '20201210',
#    'isbn': '1189184079 9791189184070',
#    'description': '‘<b>스프링</b> 프레임워크를 좀 더 간단히 사용할 수는 없을까?’\n이 책의 시작은 위의 질문에서 시작합니다. 좀 더 빠르게 개발하면서 <b>스프링</b> 프레임워크의 모든 기능을 활용할 수 있는 <b>스프링</b> 부트는 INTELLIJ나 이클립스, VS CODE 등 개발 도구들의 지원 역시 활발합니다. <b>스프링</b> 부트의 경우 자동 설정... '},
#   {'title': 'ITQ엑셀 2016(2020)(이공자)(<b>스프링</b>) (자동채점프로그램 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16360122',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/601/16360122.jpg?type=m1&udate=20200526',
#    'author': 'KIE 기획연구실',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '아카데미소프트',
#    'pubdate': '20200511',
#    'isbn': '8984550159 9788984550155',
#    'description': '- 새롭게 변경된 시험유형을 모두 반영한 최신교재!\n- 최신 자동채점프로그램 무료 제공!\n\n● 출제유형 완전정복하기 \n최근에 출제된 ITQ 시험의 출제유형을 분석하여 새롭게 변경된 내용과 시험에 자주 출제되는 부분을 단계별로 체크하고 작성할 수 있도록 구성하였습니다. \n● 유형정복 모의고사\n출제유형... '},
#   {'title': '신비아파트 하루 한 장 : 한자 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18215370',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/182/153/18215370.jpg?type=m1&udate=20210405',
#    'author': '서울문화사 편집부',
#    'price': '18000',
#    'discount': '14400',
#    'publisher': '서울문화사',
#    'pubdate': '20210323',
#    'isbn': '9170011206 8809170011203',
#    'description': '신비아파트 친구들과 함께\n신나게 배우고 써 보는 한자 150자!신비아파트 한자 사전〉을 쓰기 책으로 재구성!\n〈신비아파트 하루 한 장 한자〉는 〈신비아파트 고스트볼X의 탄생 한자 사전〉에서 수록되었던 8~7급 한자를 비롯하여, 사전에 수록하지 못한 나머지 8~7급 한자를 모두 담았습니다. 이 책에서는... '},
#   {'title': '<b>스프링</b> 인 액션(5판) (<b>스프링</b> 5의 강력한 기능과 생산성을 활용한 웹 애플리케이션 개발)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16348386',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/483/16348386.jpg?type=m1&udate=20201017',
#    'author': '크레이그 월즈',
#    'price': '35000',
#    'discount': '31500',
#    'publisher': '제이펍',
#    'pubdate': '20200514',
#    'isbn': '1190665182 9791190665186',
#    'description': '리액티브 프로그래밍 지원을 강화한 <b>스프링</b> 5의 모든 것을 탐구한다!이 책에서는 <b>스프링</b> 5와 <b>스프링</b> 부트 2를 사용해서 애플리케이션을 개발하는 데 필요한 여러  핵심 기능을 알려줍니다. <b>스프링</b> 5에서는 특히 새로운 리액티브 웹 프레임워크인 WEBFLUX를 중점적으로 다룹니다. 개발자들은 더 쉽고 확장성이... '},
#   {'title': '또래 퀴즈: 상식 퀴즈 백과(<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18985011',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/189/850/18985011.jpg?type=m1&udate=20210416',
#    'author': '강영훈',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '이젠교육',
#    'pubdate': '20210415',
#    'isbn': '1197068457 9791197068454',
#    'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 상식 퀴즈 백과≫에는 일반, 직업, 세계, 한국, 인물, 동물, 공룡 등에 관한 다양하고 재미있는 상식 퀴즈가... '},
#   {'title': 'ITQ 파워포인트 2016(2020)(이공자)(<b>스프링</b>) (최신 자동채점프로그램 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16283043',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/830/16283043.jpg?type=m1&udate=20210313',
#    'author': 'KIE 기획연구실',
#    'price': '16000',
#    'discount': '',
#    'publisher': '아카데미소프트',
#    'pubdate': '20200226',
#    'isbn': '8984550043 9788984550049',
#    'description': '최근에 출제된 ITQ 시험의 출제유형을 분석하여 새롭게 변경된 내용과 시험에 자주 출제되는 부분을 단계별로 체크하고 작성할 수 있도록 구성하였다. 출제유형 완전정복에서 학습한 내용을 바탕으로 시험에 대한 전반적인 유형을 파악하고 실력을 향상시킬 수 있도록 모의고사를 구성하였으며, 2020년 7월... '},
#   {'title': '흑박물관 고스트 앤드 레이디 상.하 박스 세트 - 전2권 (흑박물관 <b>스프링</b>갈드 포함)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18862291',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/188/622/18862291.jpg?type=m1&udate=20210410',
#    'author': '후지타 카즈히로',
#    'price': '27000',
#    'discount': '24300',
#    'publisher': '학산문화사(만화)',
#    'pubdate': '20210330',
#    'isbn': '1134879814 9791134879815',
#    'description': '서커스〉, 〈쌍망정은 부숴야 한다〉 등으로 우리에게 잘 알려진 작가 \n후지타 카즈히로의 기발한 상상력으로 그린 도시괴담 시리즈의 2탄이다.\n1탄 〈<b>스프링</b>갈드〉와 함께 박스판으로도 만나볼 수 있는 이번 기획은 작가의\n팬은 물론, 고딕풍의 배경을 좋아하는 독자라면 한 번쯤 꼭 소장하게 될 한권이다.'},
#   {'title': '<b>스프링</b>북 교과서 가로세로 낱말퍼즐(고급)(<b>스프링</b>) (초등학생 필수 어휘 총출동!)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16853362',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/168/533/16853362.jpg?type=m1&udate=20201029',
#    'author': '김수웅',
#    'price': '9800',
#    'discount': '8820',
#    'publisher': '시간과공간사',
#    'pubdate': '20201130',
#    'isbn': '1190818086 9791190818087',
#    'description': '시리즈 모두 고급스러운 <b>스프링</b>제본으로 아이들이 쉽게 책장을 넘기고 필기할 수 있도록 도왔습니다. 모든 공부의 기본은 어휘력이라는 말처럼, 우리 아이들이 이 책을 놀이 삼아 풀면서 어휘력을 향상시키고 탄탄한 학업의 기초를 쌓기를 바라는 저자의 진심이 온전히 전해지기를 바랍니다.'},
#   {'title': '또래퀴즈: 사회 문화 퀴즈백과(<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18985010',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/189/850/18985010.jpg?type=m1&udate=20210416',
#    'author': '최인수',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '이젠교육',
#    'pubdate': '20210415',
#    'isbn': '1197068449 9791197068447',
#    'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 사회 문화 퀴즈 백과≫에는 사회.문화와 관련한 한국사, 세계사, 경제, 한국지리, 문화 및 문화재, 상식... '},
#   {'title': '아이유 베스트 피아노 스코어(<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16215057',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/150/16215057.jpg?type=m1&udate=20200207',
#    'author': '라몽 피아노(김정현)',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '음악세계',
#    'pubdate': '20200205',
#    'isbn': '8966855407 9788966855407',
#    'description': '대한민국 최고의 여성 싱어송라이터 아이유의 베스트 25곡을 마피아(마음만은 피아니스트) 컴퍼니 전속 편곡자이자 인기 피아노 유튜버인 라몽 피아노가 편곡한 피아노 악보집입니다. 최신곡 ‘첫 겨울이니까’와 최근 앨범 「LOVE POEM」의 전곡, 그리고 그동안 발매된 아이유 앨범의 모든 타이틀 곡을... '},
#   {'title': '<b>스프링</b>으로 하는 마이크로서비스 구축 (<b>스프링</b> 부트와 <b>스프링</b> 클라우드를 이용한 도커)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17469720',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/174/697/17469720.jpg?type=m1&udate=20201211',
#    'author': '매그너스 라슨',
#    'price': '40000',
#    'discount': '36000',
#    'publisher': '에이콘출판',
#    'pubdate': '20201130',
#    'isbn': '1161754679 9791161754673',
#    'description': '★ 요약 ★\n\n기존 일체형 애플리케이션을 마이크로서비스로 나누고 온프레미스나 클라우드로 배포하려는 자바, <b>스프링</b> 개발자와 아키텍트를 위한 책이다. \n<b>스프링</b> 부트, <b>스프링</b> 클라우드와 도커, 쿠버네티스, 이스티오, EFK 스택, 프로메테우스, 그라파나 등의 오픈 소스 도구를 조합해 마이크로서비스를... '},
#   {'title': '깜놀 히브리어 1(<b>스프링</b>) (재미있게 배우는 그림 연상 히브리어)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16417228',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/172/16417228.jpg?type=m1&udate=20200725',
#    'author': '이요엘',
#    'price': '30000',
#    'discount': '27000',
#    'publisher': '두란노서원',
#    'pubdate': '20200715',
#    'isbn': '8953137918 9788953137912',
#    'description': '머리에서 증발되는 히브리어는 이제 안녕~\n깜놀 그림 암송법으로 히브리어가 술술히브리어를 두 번이나 낙제한 경험이 있는 저자가 만든 히브리어 교재\n저자인 이요엘 교수는 히브리어를 두 번이나 낙제했다고 한다. 괴로워하며 눈물을 흘리고 한참을 기도했는데, 하나님은 이런 마음을 주셨다.\n‘단어를 먼저... '},
#   {'title': '헤븐피아노 CCM 워십악보 2 (<b>스프링</b>) (마커스워십, 어노인팅, 위러브, 제이워십, 찬미워십 등)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16386299',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/862/16386299.jpg?type=m1&udate=20201012',
#    'author': '김선희',
#    'price': '21000',
#    'discount': '18900',
#    'publisher': '분명한소리',
#    'pubdate': '20200622',
#    'isbn': '1197025103 9791197025105',
#    'description': '▶ 피아노 혼자 연주할 때를 고려하여 편곡하였습니다.\n▶ 다른 악기의 역할을 표현하는 방법도 담았습니다.\n▶ <b>스프링</b> 북으로 편하게 연습하실 수 있습니다.\n▶ 모든 곡은 큐알(Q.R) 코드가 있어, 연주 영상을 확인할 수 있습니다.\n▶ 모든 곡에 헤븐피아노 연주 팁(TIP)을 담았습니다.'},
#   {'title': '헤븐피아노 실전 반주악보 6 (<b>스프링</b>) (기본 코드)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17525461',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/175/254/17525461.jpg?type=m1&udate=20201203',
#    'author': '김선희|김현우',
#    'price': '21000',
#    'discount': '18900',
#    'publisher': '분명한소리',
#    'pubdate': '20201202',
#    'isbn': '1197025111 9791197025112',
#    'description': '▶ PART.1 기본 코드 - 정확한 보이싱으로 깔끔하게 연주하기\n▶ PART.2 실전 반주 CCM 10곡과 헤븐피아노 연주 팁(TIP)\n▶ PART.3 찬송가 리하모니제이션 10곡을 여러 버전으로 담았습니다.\n▶ <b>스프링</b> 북으로 편하게 연습하실 수 있습니다.\n▶ 모든 곡은 큐알(Q.R) 코드가 있어, 연주 영상을 확인할 수 있습니다.'},
#   {'title': 'ITQ 한글 ver.2010(이기적)(<b>스프링</b>) (최신 출제기준 분석 + 동영상 강의 무료 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16430071',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/300/16430071.jpg?type=m1&udate=20200729',
#    'author': '영진정보연구소',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '영진닷컴',
#    'pubdate': '20200720',
#    'isbn': '8931463103 9788931463101',
#    'description': '본 도서는 ITQ 한글 시험 경향을 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서입니다. 한글 VER.2010을 기준으로 작성되었으며, 2020년 7월 공식 시험버전이 2016으로 변경되었지만 2021년까지 2010버전도 응시가 가능하므로 상황에 맞게 선택하실 수 있습니다.\n꼼꼼이론과 유형을 확인하는... '},
#   {'title': 'JLPT N3 일본어 단어 쓰기 노트(<b>스프링</b>) (기적의 쓰기 학습법으로 공부하는)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17909741',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/179/097/17909741.jpg?type=m1&udate=20210303',
#    'author': '박다진',
#    'price': '13800',
#    'discount': '12420',
#    'publisher': '세나북스',
#    'pubdate': '20210125',
#    'isbn': '118731675X 9791187316756',
#    'description': '머리와 손이 기억하는 ‘기적의 쓰기 학습법’으로\n일본어 기본 단어를 마스터하자!\n출제 빈도 높은 JLPT N3 단어 1,024개 수록!\nJLPT(일본어능력시험) N3에서 반드시 알아야 하고 실생활에서 자주 사용하는 일본어 필수 단어와 한자를 관련 문장을 직접 쓰면서 익힐 수 있도록 구성하였습니다. 단어만 학습하는... '},
#   {'title': '<b>스프링</b>북 스도쿠 1 (초급 중급)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13069530',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/130/695/13069530.jpg?type=m1&udate=20180105',
#    'author': '시간과공간사 편집부',
#    'price': '7500',
#    'discount': '6750',
#    'publisher': '시간과공간사',
#    'pubdate': '20180108',
#    'isbn': '8971429917 9788971429914',
#    'description': '머리는 쓰면 쓸수록 두뇌가 깨어난다!&#x0D;스마트폰에 익숙한 현대인의 두뇌회전에 도움을!&#x0D;&#x0D;요즘 스마트폰을 사용하지 않는 사람을 보기가 어려울 정도로 우리는 스마트폰 사용률이 높다. 그러다 보니 하루 일과를 스마트폰과 함께 하는 시간이 대부분이다. 오죽하면 스마트폰 제한 앱까지 나왔을까... '},
#   {'title': '실전! <b>스프링</b> 5와 Vue.js 2로 시작하는 모던 웹 애플리케이션 개발 (<b>스프링</b> 부트와 Vuex를 활용한 실습 중심의 풀스택 웹 애플리케이션 개발)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16113469',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/161/134/16113469.jpg?type=m1&udate=20200114',
#    'author': '제임스 J. 예 저|김현만,권봉혁,변준석',
#    'price': '36000',
#    'discount': '32400',
#    'publisher': '위키북스',
#    'pubdate': '20200121',
#    'isbn': '1158391854 9791158391850',
#    'description': '프런트엔드와 백엔드 웹 개발에서 <b>스프링</b>과 VUE를 사용해 효율성을 높이자!이 책은 실용적인 접근법으로 풀스택 웹 개발자가 되는 데 도움을 줍니다.... 이 책을 통해 웹 애플리케이션을 개발하는 방법을 배우면서 <b>스프링</b> 5와 VUE.JS 2에 익숙해질 것입니다. 초기 구조화부터 전체 배포까지, VUE.JS 2와 <b>스프링</b> 5를... '},
#   {'title': 'ACL 김중근 형사소송법 서브노트 (<b>스프링</b>) (경찰채용 / 경찰간부 / 경찰승진 / 법원직 / 검찰직 / 해경 / 해경간부 / 교정직 / 소방직 / 출입국관리직)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16686416',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/166/864/16686416.jpg?type=m1&udate=20201020',
#    'author': '김중근',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '에이씨엘커뮤니케이션',
#    'pubdate': '20200914',
#    'isbn': '1165230992 9791165230999',
#    'description': '〈이 책의 특징〉\n\n판서 내용 완벽 정리\n중요 기출과 조문을 OX 문제로 수록[100% 지문 교체]\n최신 개정법 반영[통신비밀보호법]\n\n[부록]\n두문자 암기법, 주의할 조문, 숫자 정리\n시험에 필요한 주옥같은 멘트\n할 수 있다/하여야 한다'},
#   {'title': '벨라앤루카스 포핸즈 연주곡집 (Original Ver.) (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16120927',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/161/209/16120927.jpg?type=m1&udate=20200115',
#    'author': '벨라 앤 루카스',
#    'price': '18000',
#    'discount': '16200',
#    'publisher': '삼호ETM',
#    'pubdate': '20200122',
#    'isbn': '8967212003 9788967212001',
#    'description': '최신 가요, 영화 및 드라마 OST를 포핸즈 피아노로 새롭게 재해석하여 연주하는 벨라앤루카스!피아노 듀엣 부문 구독자 44만 명! 유튜브에서 가장 핫한 듀엣 피아니스트 ‘벨라앤루카스’의 포핸즈 연주곡집입니다. 최신 드라마, 영화 OST부터 케이팝, 클래식까지! 둘이 연주해서 더 좋은 포핸즈 커버를... '},
#   {'title': '최진우 독한국사 독심술 찐[眞] (<b>스프링</b>) (독한국사 심플한 이론정리 술술 읽히는 요약서)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16626683',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/166/266/16626683.jpg?type=m1&udate=20200826',
#    'author': '최진우',
#    'price': '22000',
#    'discount': '19800',
#    'publisher': '더나은',
#    'pubdate': '20201007',
#    'isbn': '1190837129 9791190837125',
#    'description': '독한국사 심플한 이론정리 술술 읽히는 요약서\n\n1. 빈틈없이 정리한 완전무결 진짜 한국사 요약서\n2. 이 한권으로 이론(기본+심화) 정리와 암기를 한번에 완성\n3. 한 눈에 들어오는 체계적인 시대사 도표\n4. 헷갈리는 한국사 이론을 테마별 분류로 쉽게 이해\n5. 최신 공무원 기출 + 8종 고등 교과서 내용 완벽 반영... '},
#   {'title': '2021 손에 잡히는 꼼꼼한 의학이론 요약집 (<b>스프링</b>) (신체손해사정사 2차 의학이론)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18862352',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/188/623/18862352.jpg?type=m1&udate=20210330',
#    'author': '정혜심',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '고시아카데미(한국금융보험방송)',
#    'pubdate': '20210325',
#    'isbn': '8966311962 9788966311965',
#    'description': ''},
#   {'title': '코드로 배우는 <b>스프링</b> 웹 프로젝트 (현업 개발을 위한 단계별 실습서)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13993776',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/139/937/13993776.jpg?type=m1&udate=20210128',
#    'author': '구멍가게 코딩단',
#    'price': '38000',
#    'discount': '34200',
#    'publisher': '남가람북스',
#    'pubdate': '20180913',
#    'isbn': '118918401X 9791189184018',
#    'description': '이 책은 SPRING FRAMEWORK(이하 <b>스프링</b>)를 사용해서 말 그대로 ‘웹 프로젝트’를 어떻게 진행하는지를 설명하는 책입니다. 웹 프로젝트라고 거창하게 표현하지만, 좀 더 구체적으로는 <b>스프링</b>으로 웹... 독자]\n<b>스프링</b>으로 웹 프로젝트를 진행하기 위해서는 다음과 같은 선행학습이 필요합니다. \n* JAVA 언어에... '},
#   {'title': '마이 스위트 카페 스티커 컬러링북 (<b>스프링</b>) + 아르누보 36색 색연필 세트',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16388820',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/888/16388820.jpg?type=m1&udate=20200624',
#    'author': '이수현',
#    'price': '30000',
#    'discount': '10000',
#    'publisher': '아르누보',
#    'pubdate': '20200528',
#    'isbn': '9474875650 8809474875655',
#    'description': '당신이 꿈꾸는 달콤한 쉼터는 어떤 색인가요?\n스위트 카페의 감성을 담은 컬러링 스티커에\n나만의 색을 입혀 보세요.바쁜 일상에 지친 당신에게 《마이 스위트 카페 스티커 컬러링북》이 맛있는 행복을 가득 담은 300개의 다양한 컬러링 스티커를 선물합니다. \n감미로운 커피 향기를 따라가면 발견할 수 있는... '},
#   {'title': '뚝딱뚝딱 입체 종이접기 2 (<b>스프링</b>) (동물, 로봇)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=19007739',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/190/077/19007739.jpg?type=m1&udate=20210422',
#    'author': '이지숙',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '스쿨존(굿인포메이션)',
#    'pubdate': '20210415',
#    'isbn': '1197415114 9791197415111',
#    'description': '놀이와 두뇌계발, 두 마리 토끼를 동시에!!!\n\n똥손 엄마 도전!\n만들기 잼병 아빠도 함께!\n산만한 우리아이와 함께 할 입체 종이접기!\n\n아이 얼굴만 쳐다보고 있을 수도 없고,\n같이 놀아주려 해도 체력이 따라주지 않고,\n마냥 유튜브만 틀어줄 수는 없고...\n함께 노는 것도 고민해야 해?!?\n\n얼굴만 쳐다보고 있어도... '},
#   {'title': '뚝딱뚝딱 입체 종이접기 3 (<b>스프링</b>) (탈것(하늘.물), 공룡, 집)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=19007734',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/190/077/19007734.jpg?type=m1&udate=20210422',
#    'author': '이지숙',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '스쿨존(굿인포메이션)',
#    'pubdate': '20210415',
#    'isbn': '1197415122 9791197415128',
#    'description': '놀이와 두뇌계발, 두 마리 토끼를 동시에!!!\n\n똥손 엄마 도전!\n만들기 잼병 아빠도 함께!\n산만한 우리아이와 함께 할 입체 종이접기!\n\n아이 얼굴만 쳐다보고 있을 수도 없고,\n같이 놀아주려 해도 체력이 따라주지 않고,\n마냥 유튜브만 틀어줄 수는 없고...\n함께 노는 것도 고민해야 해?!?\n\n얼굴만 쳐다보고 있어도... '},
#   {'title': '뚝딱뚝딱 입체 종이접기 1 (<b>스프링</b>) (탈것(땅), 큐브)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=19007735',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/190/077/19007735.jpg?type=m1&udate=20210422',
#    'author': '이지숙',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '스쿨존(굿인포메이션)',
#    'pubdate': '20210415',
#    'isbn': '1197415106 9791197415104',
#    'description': '놀이와 두뇌계발, 두 마리 토끼를 동시에!!!\n\n똥손 엄마 도전!\n만들기 잼병 아빠도 함께!\n산만한 우리아이와 함께 할 입체 종이접기!\n\n아이 얼굴만 쳐다보고 있을 수도 없고,\n같이 놀아주려 해도 체력이 따라주지 않고,\n마냥 유튜브만 틀어줄 수는 없고...\n함께 노는 것도 고민해야 해?!?\n\n얼굴만 쳐다보고 있어도... '},
#   {'title': '내손에 헌법 (<b>스프링</b>) (헌법조문집 : 이해를 통한 손에 잡히는 헌법, 제5판)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16365572',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/655/16365572.jpg?type=m1&udate=20200626',
#    'author': '윤우혁',
#    'price': '10000',
#    'discount': '9500',
#    'publisher': '박영사',
#    'pubdate': '20200615',
#    'isbn': '113033659X 9791130336596',
#    'description': '- 독자대상 : 7급 9급 국회직 법원 검찰직 법무사 경찰승진 변호사 5급공채 시험 준비생\n- 구성 및 특징 : 이론'},
#   {'title': '또래 퀴즈 : 호기심 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825226',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825226.jpg?type=m1&udate=20210129',
#    'author': '강영훈 지음|원혜진',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '이젠교육',
#    'pubdate': '20201005',
#    'isbn': '1197068430 9791197068430',
#    'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 호기심 퀴즈 백과≫에는 사람(인체), 동물, 식물, 지구, 자연(환경), 상식 등에 관한 다양하고 재미있는... '},
#   {'title': '시와찬미. 11(<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16419267',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/192/16419267.jpg?type=m1&udate=20200727',
#    'author': 'SFC출판부',
#    'price': '25000',
#    'discount': '22500',
#    'publisher': 'SFC출판부',
#    'pubdate': '20200717',
#    'isbn': '118794243X 9791187942436',
#    'description': '- 시와 찬미 11은 악보집 이용자들이 선호하는 <b>스프링</b> 제본 방식으로 제작되었습니다.\n\n- 시와 찬미11에는 607곡들이 주제별, 코드별로 분류되어 수록되어 있습니다. \n\n- 시와 찬미 11의 주제별 분류는 경배와 찬양, 은혜와 사랑, 회개와 고백, 기도와 간구, 축복과 교제, 선교와 승리로 되어 있습니다.\n- 가사 첫 줄... '},
#   {'title': '하모니카 트로트 콘서트곡집 (<b>스프링</b>) (미스 & 미스터 트롯 히트곡 모음)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17941830',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/179/418/17941830.jpg?type=m1&udate=20210209',
#    'author': '제임스 정',
#    'price': '22000',
#    'discount': '19800',
#    'publisher': '일신서적',
#    'pubdate': '20210310',
#    'isbn': '8936627589 9788936627584',
#    'description': '● 1920년대부터 2020 [미스트롯] ㆍ [미스터트롯]의 인기곡과\n   최신 히트곡을 수록한 하모니카 연주곡집\n\n● 하모니카 숫자악보의 칼라화로 연주에 편리함 \n\n● QR코드를 사용하여 약 80명의 하모니카 연주자의 연주를 \n   유튜브 영상으로 직접 보면서 듣고 즐길 수 있습니다.'},
#   {'title': '<b>스프링</b>북 스도쿠 2 (고급 고수)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13069531',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/130/695/13069531.jpg?type=m1&udate=20200522',
#    'author': '편집부|스도쿠 존 연구소',
#    'price': '7500',
#    'discount': '6750',
#    'publisher': '시간과공간사',
#    'pubdate': '20180108',
#    'isbn': '8971429925 9788971429921',
#    'description': '머리는 쓰면 쓸수록 두뇌가 깨어난다!&#x0D;스마트폰에 익숙한 현대인의 두뇌회전에 도움을!&#x0D;&#x0D;요즘 스마트폰을 사용하지 않는 사람을 보기가 어려울 정도로 우리는 스마트폰 사용률이 높다. 그러다 보니 하루 일과를 스마트폰과 함께 하는 시간이 대부분이다. 오죽하면 스마트폰 제한 앱까지 나왔을까... '},
#   {'title': '초보 웹 개발자를 위한 <b>스프링</b>5 프로그래밍 입문',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13786861',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/137/868/13786861.jpg?type=m1&udate=20180724',
#    'author': '최범균',
#    'price': '26500',
#    'discount': '23850',
#    'publisher': '가메',
#    'pubdate': '20180720',
#    'isbn': '8980782977 9788980782970',
#    'description': '<b>스프링</b> 프레임워크의 버전업으로 개선된 내용을 담았습니다.\n\n필자의 한마디 : 처음 <b>스프링</b>을 배우고자 하는 독자들이 입문할 때 필요한 것은 <b>스프링</b>의 방대한 내용이 아닌 기초와 전반적인 흐름을 잡아주는 것으로 생각한다.\n\n● <b>스프링</b> DI 기초와 의존 자동 주입\n● <b>스프링</b> AOP 기초\n● <b>스프링</b>을... '},
#   {'title': '수채화 캘리 성경 365 (<b>스프링</b>) (매일 아침 수채화 캘리그라피로 만나는 말씀 묵상)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17652047',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/176/520/17652047.jpg?type=m1&udate=20210119',
#    'author': '김영선|박광철',
#    'price': '13000',
#    'discount': '11700',
#    'publisher': '티나',
#    'pubdate': '20201230',
#    'isbn': '1188417231 9791188417230',
#    'description': '감사와 은혜로 시작하는 매일 아침!\n따뜻한 수채화와 캘리그라피로 만나는 말씀 묵상!『수채화 캘리 성경 365』를 넘기며 감사와 은혜로 하루를 시작해 보자. 감성적인 캘리그라피로 쓰인 성경 구절과 그에 어울리는 정갈한 수채화, 목사님의 성경 말씀 해설을 한 장씩 읽다 보면 은혜가 충만해짐을 느낄 수... '},
#   {'title': '내 인생의 <b>스프링</b> 캠프 (블루픽션 22)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=2954171',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/029/541/02954171.jpg?type=m1&udate=20200305',
#    'author': '정유정',
#    'price': '11000',
#    'discount': '9900',
#    'publisher': '비룡소',
#    'pubdate': '20070701',
#    'isbn': '8949120763 9788949120768',
#    'description': "2007년 제1회 세계청소년문학상 수상작\n\n어느 날 갑자기 낯선 세상으로 뛰어든 열다섯 살 세 애송이들이 펼치는 '개판' 여행. 청룡열차를 탄 것 같은 속도감 있는 문체, 유머 가득 담긴 입담 속에 펼쳐지는 십대들의 풋풋한 사랑과 그 비밀스러운 성장 이야기로, 2007년 제1회 세계청소년문학상 수상작이다.\n\n소설은... "},
#   {'title': '토비의 <b>스프링</b> 3.1 세트 (<b>스프링</b>의 이해와 원리 + <b>스프링</b>의 기술과 선택, 전2권)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=7006516',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/070/065/07006516.jpg?type=m1&udate=20151005',
#    'author': '이일민',
#    'price': '75000',
#    'discount': '67500',
#    'publisher': '에이콘출판',
#    'pubdate': '20120921',
#    'isbn': '8960773433 9788960773431',
#    'description': '『토비의 <b>스프링</b> 3.1』은 <b>스프링</b>을 처음 접하거나 <b>스프링</b>을 경험했지만 <b>스프링</b>이 어렵게 느껴지는 개발자부터 <b>스프링</b>을 활용한 아키텍처를 설계하고 프레임워크를 개발하려고 하는 아키텍트에 이르기까지 모두 참고할 수 있는 <b>스프링</b> 완벽 바이블이다.[Vol. 1 <b>스프링</b>의 이해와 원리] 단순한 예제를... '},
#   {'title': '슬기로운 의사생활 OST 피아노 연주곡집(OST 사운드북 시리즈 1)(<b>스프링</b>) (OST 전곡수록)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16408113',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/081/16408113.jpg?type=m1&udate=20200711',
#    'author': '나정현 (편곡)|정다운 (편곡)|채경원',
#    'price': '12000',
#    'discount': '10800',
#    'publisher': '그래서음악(somusic)',
#    'pubdate': '20200720',
#    'isbn': '1197092501 9791197092503',
#    'description': '모범연주 QR코드, 상세한 코드와 가사가 제공되며 연주할 때 넘기기 쉽게 제작된 <b>스프링</b> 악보로 편리함을 더했습니다. 그 시절 우리가 즐겨듣고 따라 불렀던 추억의 인기가요를 피아노로 연주하며 드라마 속 감동과 여운을 다시 한번 느껴보세요.'},
#   {'title': '어린왕자 탁상달력: 체크 리스트형(2021)(<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17193964',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/171/939/17193964.jpg?type=m1&udate=20201222',
#    'author': '미르북컴퍼니 편집부',
#    'price': '7500',
#    'discount': '4500',
#    'publisher': '미르북컴퍼니(미르북스)',
#    'pubdate': '20201105',
#    'isbn': '9529011725 8809529011724',
#    'description': '『어린왕자 탁상달력: 체크 리스트형(2021)』은 세상에서 가장 순수한 영혼 별처럼 빛나는 어린 왕자와 2021년을 만난다. 앞면에 체크리스트가 있어 매월 중요한 일정을 기입할 수 있다.'},
#   {'title': '배워서 바로 쓰는 <b>스프링</b> 프레임워크 (AOP, 보안, 메시징부터 <b>스프링</b> 웹 MVC까지 실용적인 예제로 한눈에 알아보는 <b>스프링</b> 가이드,Getting started with Spring Framework)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16339880',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/398/16339880.jpg?type=m1&udate=20200601',
#    'author': '애시시 사린,제이 샤르마 공저|오현석',
#    'price': '50000',
#    'discount': '45000',
#    'publisher': '한빛미디어',
#    'pubdate': '20200501',
#    'isbn': '116224304X 9791162243046',
#    'description': '88가지 단계별 프로젝트로 익히는 <b>스프링</b> 프레임워크\n이 책은 <b>스프링</b> 5 기본과 개념, 최신 업데이트된 프레임워크 전반을 단계별로 접근합니다. IoC 컨테이너 같은 <b>스프링</b> 기초부터 <b>스프링</b> 데이터, <b>스프링</b> AOP, <b>스프링</b> 메시징, <b>스프링</b> 웹 MVC, 스트림 API, <b>스프링</b> 시큐리티, RESTful 웹 서비스, 반응형... '},
#   {'title': '또래 퀴즈 : 과학 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825221',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825221.jpg?type=m1&udate=20201028',
#    'author': '강영훈',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '이젠교육',
#    'pubdate': '20201005',
#    'isbn': '1197068422 9791197068423',
#    'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 과학 퀴즈 백과≫에는 과학 현상, 미래과학, 우주, 별과 별자리, 지구와 날씨, 생명과 건강 등에 관한... '},
#   {'title': '기본인체해부학 강의노트 (<b>스프링</b>) (간호·보건대생 실습을 위한)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17895224',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/178/952/17895224.jpg?type=m1&udate=20210223',
#    'author': '김인범',
#    'price': '25000',
#    'discount': '24250',
#    'publisher': '범문에듀케이션',
#    'pubdate': '20210201',
#    'isbn': '1159432325 9791159432323',
#    'description': '『기본인체해부학 강의노트』는 〈뼈대, 관절 및 근육계통〉, 〈순환, 신경 및 피부계통〉, 〈등〉, 〈팔〉, 〈다리〉, 〈얼굴과 목〉 등을 수록하고 있는 책이다.'},
#   {'title': '마블 스튜디오 캡틴 마블 위클리 플래너 (구스 Ver) (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14789245',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/147/892/14789245.jpg?type=m1&udate=20190416',
#    'author': 'Marvel',
#    'price': '8000',
#    'discount': '1900',
#    'publisher': '아르누보',
#    'pubdate': '20190422',
#    'isbn': '9474872821 8809474872821',
#    'description': 'ㆍ들고 다니면서 써도 튼튼한 양장 표지와 넘기기 편한 <b>스프링</b> 제본이 되어 있습니다.\nㆍ일주일의 일정을 한눈에 볼 수 있는 위클리 플래너입니다.\nㆍ앞면 위클리와 뒷면 노트로 반복됩니다. 월과 요일을 자유롭게 쓸 수 있습니다.\n\n당신의 일상의 든든한 파트너가 되어 줄 《캡틴 마블 위클리 플래너-구스 VER.... '},
#   {'title': 'DIAT 프리젠테이션(파워포인트 2010)(발자취)(<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16267940',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/679/16267940.jpg?type=m1&udate=20200229',
#    'author': '수험서개발팀',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '마린북스',
#    'pubdate': '20200210',
#    'isbn': '1190402122 9791190402125',
#    'description': '한국정보통신진흥협회 시행\n국가공인 디지털정보활용능력(DIAT)\n시험 준비에 최적화된 수험서입니다.★ 시험 준비에 필요한 모든 과정을 처음부터 순서대로 구성하여 빈틈없이 시험을 준비할 수 있습니다.\n★ 기능별 학습이 아니라 따라하기식으로 시험 문제를 풀어나가도록 구성하여 쉽게 학습할 수... '},
#   {'title': '낭만의 통기타 고급 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17526327',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/175/263/17526327.jpg?type=m1&udate=20201209',
#    'author': '박해민',
#    'price': '20000',
#    'discount': '18000',
#    'publisher': '민스뮤직출판',
#    'pubdate': '20201126',
#    'isbn': '1195473885 9791195473885',
#    'description': '“낭만의 통기타”는 중장년층이 문화센터나 주민센터, 동호회에서 통기타를 배우기에 적합하게 구성하여 만들어진 교재를 겸한 연주곡집입니다.'},
#   {'title': '또래 퀴즈 : 세계 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825225',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825225.jpg?type=m1&udate=20201028',
#    'author': '최인수 지음|박지원',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '이젠교육',
#    'pubdate': '20201005',
#    'isbn': '1197068406 9791197068409',
#    'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 세계 퀴즈 백과≫에는 세계의 나라, 명소, 문화재, 도시, 음식, 의복, 풍속, 건축에 관한 다양하고 재미있는... '},
#   {'title': '독한국사 독심술 is 100(2)핵심유형 문제집.(최진우)(<b>스프링</b>) (독한국사 심화이론 술술 풀리는 문제 풀이)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16344443',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/444/16344443.jpg?type=m1&udate=20200605',
#    'author': '최진우',
#    'price': '23000',
#    'discount': '20700',
#    'publisher': '더나은',
#    'pubdate': '20200515',
#    'isbn': '1187618624 9791187618621',
#    'description': '- 독자대상 : 공무원 시험 준비생\n- 구성 및 특징 : \n① 최근 경향 반영\n② 학습 내용 체계적으로 구성'},
#   {'title': '로보카폴리 썼다 지웠다 한글 똑똑(<b>스프링</b>) (한글 낱말 195개를 썼다 지웠다!)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16236950',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/369/16236950.jpg?type=m1&udate=20200814',
#    'author': '로이비쥬얼',
#    'price': '12000',
#    'discount': '8400',
#    'publisher': '로이북스',
#    'pubdate': '20200203',
#    'isbn': '9316331382 8809316331387',
#    'description': '<b>스프링</b> 제본으로 책이 쫙 펼쳐져 글씨 쓰기 편하고, 지우개가 달린 자석 보드펜을 책에 쏙 끼워 보관할 수 있어요. 아이 입장에서 생각하며, 꼼꼼하고, 편리하게 만들었답니다. \n초등학교 교과서의 한글 쓰기 획순에 따라 한글 자음과 모음, 다양한 낱말을 고딕체 글씨로 또박또박 따라 쓰기 쉽게 구성했어요.... '},
#   {'title': '또래 퀴즈 : 인물 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825224',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825224.jpg?type=m1&udate=20201028',
#    'author': '최인수',
#    'price': '10000',
#    'discount': '9000',
#    'publisher': '이젠교육',
#    'pubdate': '20201005',
#    'isbn': '1197068414 9791197068416',
#    'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 인물 퀴즈 백과≫에는 인물과 관련한 장소, 역사, 과학, 예술, 사회, 문화, 나라 등에 관한 다양하고... '},
#   {'title': '<b>스프링</b> 입문을 위한 자바 객체 지향의 원리와 이해',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=8920762',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/089/207/08920762.jpg?type=m1&udate=20170602',
#    'author': '김종민',
#    'price': '25000',
#    'discount': '22500',
#    'publisher': '위키북스',
#    'pubdate': '20150408',
#    'isbn': '8998139944 9788998139940',
#    'description': '이 책은 자바에서 <b>스프링</b>으로 나아가기 위한 연결 고리를 제공한다.'},
#   {'title': '마이 로맨틱 유럽 스티커 컬러링북 + 마이 스위트 카페 스티커 컬러링북 - 전2권 (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16388821',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/888/16388821.jpg?type=m1&udate=20200729',
#    'author': '이수현',
#    'price': '24000',
#    'discount': '10000',
#    'publisher': '아르누보',
#    'pubdate': '20200622',
#    'isbn': '947487557X 8809474875570',
#    'description': '당신이 꿈꾸는 달콤한 쉼터는 어떤 색인가요?\n감성을 담은 컬러링 스티커에 나만의 색을 입혀 보세요.감미로운 커피 향기를 따라가면 발견할 수 있는 나만의 스위트 카페! 당신에게 달콤한 쉼터가 되어줄 멋진 카페들과 그곳에서 맛볼 수 있는 고소한 빵, 상큼한 샐러드, 달달한 케이크와 쌉쌀한 커피, 살살 녹는... '},
#   {'title': 'AKMU 악동뮤지션 피아노 연주곡집(내가 좋아하는 스타)(<b>스프링</b>) (내가 좋아하는 스타)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16744299',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/167/442/16744299.jpg?type=m1&udate=20200922',
#    'author': '김지은',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '태림스코어',
#    'pubdate': '20200930',
#    'isbn': '115780294X 9791157802944',
#    'description': '대한민국을 대표하는 남매 혼성 듀오 AKMU(악동뮤지션)!\n이 책은 음원 강자 AKMU(악동뮤지션)의 인기곡을 엄선하여 엮은 피아노 연주곡집입니다. \n일상 속의 여러 순간들을 다양한 시각과 감성으로 녹여낸 그들의 음악을 피아노로 연주할 수 있도록 체르니 30번 수준으로 편곡하여 원곡의 길이와 매력을 그대로... '},
#   {'title': 'DIAT 워드프로세서(한글 2010)(발자취)(<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16267943',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/679/16267943.jpg?type=m1&udate=20200229',
#    'author': '수험서개발팀',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '마린북스',
#    'pubdate': '20200210',
#    'isbn': '1190402130 9791190402132',
#    'description': '한국정보통신진흥협회 시행\n국가공인 디지털정보활용능력(DIAT)\n시험 준비에 최적화된 수험서입니다.★ 시험 준비에 필요한 모든 과정을 처음부터 순서대로 구성하여 빈틈없이 시험을 준비할 수 있습니다.\n★ 기능별 학습이 아니라 따라하기식으로 시험 문제를 풀어나가도록 구성하여 쉽게 학습할 수... '},
#   {'title': '이정환의 파퓰러 & 뉴에이지 컬렉션 1 (<b>스프링</b>) (개정판)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17468982',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/174/689/17468982.jpg?type=m1&udate=20201120',
#    'author': '이정환',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '음악세계',
#    'pubdate': '20201115',
#    'isbn': '8966855555 9788966855551',
#    'description': '『이정환의 파퓰러 & 뉴에이지 컬렉션(개정판)』은 막상 연주하려고 하면 너무 어렵거나, 악보는 쉽지만 단순해 곡의 묘미를 살리지 못하는 문제점을 해결할 수 있는 연주곡집으로 뉴에이지, 팝송, 샹송, 영화음악, 클래식, 가요 등 다양한 장르의 음악을 멋지고 맛깔스럽게 연주할 수 있도록 편곡하였으며... '},
#   {'title': '영문 필기체 노트 바르다 <b>스프링</b>북 (영어에 멋을 더해주는 캘리 기초용 손글씨 교본)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=12472137',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/124/721/12472137.jpg?type=m1&udate=20170824',
#    'author': '편집부',
#    'price': '13000',
#    'discount': '6500',
#    'publisher': '42미디어콘텐츠',
#    'pubdate': '20170904',
#    'isbn': '9482280288 8809482280281',
#    'description': '베스트셀러 [영문 필기체 노트 바르다]를 실용적인 <b>스프링</b>북으로 리뉴얼해 더욱 편리해진 [영문 필기체 노트 바르다 <b>스프링</b>북]으로 매일 꾸준히 영문... 활용할 수 있는 예쁜 영문 필기체를 완성할 수 있습니다. [영문 필기체 노트 바르다 <b>스프링</b>북]과 함께 나만의 멋진 영문 필기체를 마음껏 뽐내 보세요!'},
#   {'title': '색소폰 연주곡 따라하기(임희승의)(나고수 색소폰 시리즈)(<b>스프링</b>) (동영상, 사전 연습, 실전 악보)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16315127',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/163/151/16315127.jpg?type=m1&udate=20200630',
#    'author': '임희승',
#    'price': '20000',
#    'discount': '18000',
#    'publisher': '세광음악출판사',
#    'pubdate': '20200327',
#    'isbn': '8903435176 9788903435174',
#    'description': '시대에 맞는 색소폰 교본의 새로운 해법을 내놓았던 『나고수 색소폰 초급편』,  『나고수 색소폰 중·고급편』, 『쉽게 배우는 색소폰 애드리브』에 이어 이번엔 ‘YOUTUBE’라는 새로운 플랫폼과 함께 돌아온 『임희승의 색소폰 연주곡 따라하기』. 악보 중심의 교재들과 달리  ‘이론 편, 연주곡 편(중급... '},
#   {'title': '라바 어린이 스도쿠 <b>스프링</b>북 초급 중급 (두뇌 계발 × 사고력 UP)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16687985',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/166/879/16687985.jpg?type=m1&udate=20200917',
#    'author': '슈퍼스도쿠퍼즐연구소',
#    'price': '7500',
#    'discount': '6750',
#    'publisher': '바이킹',
#    'pubdate': '20201005',
#    'isbn': '8964944607 9788964944608',
#    'description': '스도쿠를 매일 풀다 보면 두뇌 계발은 물론 숫자에 흥미를 느끼고 수학이 재밌어질 것이다. 문제에 도전하고 해결하는 즐거움도 느낄 수 있다. &lt;라바 어린이 스도쿠 <b>스프링</b>북 초급&gt;, &lt;라바 어린이 스도쿠 <b>스프링</b>북 초급 중급&gt;을 만나 보자.'},
#   {'title': '<b>스프링</b> 마이크로서비스 코딩 공작소 (Spring Microservices in Action)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14371209',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/143/712/14371209.jpg?type=m1&udate=20190204',
#    'author': '존 카넬',
#    'price': '33000',
#    'discount': '29700',
#    'publisher': '길벗',
#    'pubdate': '20181221',
#    'isbn': '1160506817 9791160506815',
#    'description': '&#x0D;<b>스프링</b> 부트 2와 <b>스프링</b> 클라우드 2로 구현하며 배우는 컨테이너 기반의 마이크로서비스 &#x0D;&#x0D;마이크로서비스에서는 배포가 중요한 이슈다. <b>스프링</b> 클라우드를 사용하면 마이크로서비스의 빌드와 배포를 최소화할 수 있고, 이런 의미에서 <b>스프링</b> 부트와 <b>스프링</b> 클라우드의 조합은 매력적이다. 20년간... '},
#   {'title': '하루를 시작하는 한 줄 가톨릭 (<b>스프링</b>) (YOUCAT CALENDAR)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17727034',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/177/270/17727034.jpg?type=m1&udate=20210107',
#    'author': 'YOUCAT 재단 지음|김선태 외',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '가톨릭출판사',
#    'pubdate': '20210131',
#    'isbn': '8932117543 9788932117546',
#    'description': '하루에 하나씩 교리를 익힌다!\n처음으로 선보이는 365일 만년 교리 달력많은 신자들에게 대표적인 교리서로 자리 잡은 YOUCAT 시리즈 중 《YOUCAT》, 《YOUCAT 프렌즈》, 《DOCAT》에서 핵심적인 교리 내용을 모은 365일 만년 달력이다. 언택트 시대에 맞춰 장소에 구애받지 않고 교리를 매일 하나씩 익힐 수... '},
#   {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea A형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 박재범)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062657',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062657.jpg?type=m1&udate=20210306',
#    'author': '렉스트림 편집부',
#    'price': '9000',
#    'discount': '',
#    'publisher': '렉스트림',
#    'pubdate': '20210309',
#    'isbn': '7826745004 2597826745003',
#    'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#   {'title': 'ITQ 파워포인트 2010(2020)(이공자)(개정판)(<b>스프링</b>) (최신 자동채점프로그램 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16265070',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/650/16265070.jpg?type=m1&udate=20200226',
#    'author': 'KIE 기획연구실',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '아카데미소프트',
#    'pubdate': '20200214',
#    'isbn': '8984557676 9788984557673',
#    'description': '- 2020년 7월 정기시험부터 새롭게 변경된 시험유형을 모두 반영한 최신교재!!\n- 기출 예상문제 완벽대비!!\n- 최신 자동채점프로그램 무료 제공!!'},
#   {'title': 'ITQ 엑셀 ver.2010(이기적)(<b>스프링</b>) (최신 출제기준 분석 + 동영상 강의 무료 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16430051',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/300/16430051.jpg?type=m1&udate=20200729',
#    'author': '영진정보연구소',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '영진닷컴',
#    'pubdate': '20200720',
#    'isbn': '8931463111 9788931463118',
#    'description': '본 도서는 ITQ 엑셀 시험 경향을 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서입니다. 엑셀 VER.2010을 기준으로 작성되었으며, 2020년 7월 공식 시험버전이 2016으로 변경되었지만 2021년까지 2010버전도 응시가 가능하므로 상황에 맞게 선택하실 수 있습니다.\n꼼꼼이론과 유형을 확인하는... '},
#   {'title': 'ITQ 한쇼 2016(2020)(이공자)(<b>스프링</b>) (새롭게 변경된 시험유형을 모두 반영)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16292299',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/922/16292299.jpg?type=m1&udate=20201118',
#    'author': 'KIE기획연구실',
#    'price': '16000',
#    'discount': '14400',
#    'publisher': '아카데미소프트',
#    'pubdate': '20200316',
#    'isbn': '8984550051 9788984550056',
#    'description': '- 2020년 7월 정기시험부터 새롭게 변경된 시험유형을 모두 반영한 최신교재!!\n- 기출 예상문제 완벽대비!!\n\n● 내용설명\n● 출제유형 완전정복 \n최근에 출제된 ITQ 시험의 출제유형을 분석하여 새롭게 변경된 내용과 시험에 자주 출제되는 부분을 단계별로 체크하고 작성할 수 있도록 구성하였습니다.... '},
#   {'title': 'ITQ 파워포인트 ver.2010(이기적)(<b>스프링</b>) (최신 출제기준 분석 + 동영상 강의 무료 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16430061',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/300/16430061.jpg?type=m1&udate=20200728',
#    'author': '영진정보연구소',
#    'price': '15000',
#    'discount': '13500',
#    'publisher': '영진닷컴',
#    'pubdate': '20200720',
#    'isbn': '893146312X 9788931463125',
#    'description': '본 도서는 ITQ 파워포인트 시험 경향을 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서입니다. 파워포인트 VER.2010을 기준으로 작성되었으며, 2020년 7월 공식 시험버전이 2016으로 변경되었지만 2021년까지 2010버전도 응시가 가능하므로 상황에 맞게 선택하실 수 있습니다.\n꼼꼼한 이론과... '},
#   {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea B형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 그루비룸)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062658',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062658.jpg?type=m1&udate=20210306',
#    'author': '렉스트림 편집부',
#    'price': '9000',
#    'discount': '',
#    'publisher': '렉스트림',
#    'pubdate': '20210309',
#    'isbn': '7826758009 2597826758003',
#    'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#   {'title': '마블 스튜디오 캡틴 마블 위클리 플래너 (캡틴마블 Ver) (<b>스프링</b>)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14789244',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/147/892/14789244.jpg?type=m1&udate=20190416',
#    'author': 'Marvel',
#    'price': '8000',
#    'discount': '1900',
#    'publisher': '아르누보',
#    'pubdate': '20190422',
#    'isbn': '9474872813 8809474872814',
#    'description': 'ㆍ들고 다니면서 써도 튼튼한 양장 표지와 넘기기 편한 <b>스프링</b> 제본이 되어 있습니다.\nㆍ일주일의 일정을 한눈에 볼 수 있는 위클리 플래너입니다.\nㆍ앞면 위클리와 뒷면 노트로 반복됩니다. 월과 요일을 자유롭게 쓸 수 있습니다.\n\n당신의 일상의 든든한 파트너가 되어 줄 《캡틴 마블 위클리 플래너》와 함꼐... '},
#   {'title': 'ACL 김중근 형법 Sub Note (4판 1쇄, <b>스프링</b>) (경찰채용, 경찰간부, 경찰승진, 법원직, 검찰직 , 해경, 해경간부)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16274209',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/162/742/16274209.jpg?type=m1&udate=20210318',
#    'author': '김중근',
#    'price': '14000',
#    'discount': '12600',
#    'publisher': '에이씨엘커뮤니케이션',
#    'pubdate': '20200220',
#    'isbn': '1165230267 9791165230265',
#    'description': '- 독자대상 : 경찰채용 경찰간부 경찰승진 법원직 검찰직 해경 해경간부 시험 준비생\n- 구성 : 이론 + 문제\n- 특징 : \n① 판서 내용 정리 \n② 알아보기 쉽고 깔끔한 필기체 반영 \n③ 오답률 높은 지문을 OX 문제로 수록'},
#   {'title': '해피 스텔라 한글 숫자 알파벳 썼다 지웠다(<b>스프링</b>) (썼다 지웠다)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16405444',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/054/16405444.jpg?type=m1&udate=20200807',
#    'author': '로이비쥬얼',
#    'price': '12000',
#    'discount': '8400',
#    'publisher': '로이북스',
#    'pubdate': '20200701',
#    'isbn': '9316331447 8809316331448',
#    'description': '<b>스프링</b> 제본으로 책이 쫙 펼쳐져 글씨 쓰기 편하고, 지우개가 달린 자석 보드펜을 책에 쏙 끼워 보관할 수 있지요. 아이 입장에서 생각하며, 꼼꼼하고, 편리하게 만들었답니다.\n\n초등학교 교과서 쓰기 획순에 따라 한글과 숫자를, 영미권 쓰기 책과 교과서 쓰기 순서에 따라 알파벳을 또박또박 따라 쓰기 쉽게... '},
#   {'title': '예제로 배우는 <b>스프링</b> 부트 입문 (JSP, Oracle, MyBatis와 연동한 웹 애플리케이션 만들기)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17523749',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/175/237/17523749.jpg?type=m1&udate=20201203',
#    'author': '이재환',
#    'price': '30000',
#    'discount': '27000',
#    'publisher': '비제이퍼블릭',
#    'pubdate': '20201130',
#    'isbn': '1165920301 9791165920302',
#    'description': '<b>스프링</b> 부트의 이론부터 실전까지\n예제로 가장 쉽고 빠르게, 체계적으로 배운다!기존의 책들은 이론이 너무 많았습니다. 그래서 <b>스프링</b>을 대하는 학생들을 보면 일단 너무 어려워하거나 지루해했습니다.... 이 책에서는 <b>스프링</b> 부트에 필요한 이론은 놓치지 않고 자연스럽게 모두 익힐 수 있도록 구성하였습니다.... '},
#   {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea C형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 이승찬)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062659',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062659.jpg?type=m1&udate=20210306',
#    'author': '렉스트림 편집부',
#    'price': '9000',
#    'discount': '',
#    'publisher': '렉스트림',
#    'pubdate': '20210309',
#    'isbn': '7826769000 2597826769009',
#    'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#   {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea D형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 초록)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062660',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062660.jpg?type=m1&udate=20210306',
#    'author': '렉스트림 편집부',
#    'price': '9000',
#    'discount': '',
#    'publisher': '렉스트림',
#    'pubdate': '20210309',
#    'isbn': '782679000X 2597826790003',
#    'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#   {'title': '실전 <b>스프링</b> 부트 REST API 개발 MyBatis + MySQL 개정판',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18896291',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/188/962/18896291.jpg?type=m1&udate=20210406',
#    'author': '향단코드',
#    'price': '10000',
#    'discount': '',
#    'publisher': '온노트',
#    'pubdate': '20210406',
#    'isbn': '1190230194 9791190230193',
#    'description': '이 책은 <b>스프링</b> 부트를 이용하여 REST API 시스템을 개발하고자 하는 사람을 위한 것입니다.\n이미지를 판매하는 간단한 디지털 컨텐츠 샵의  REST API를 구축해 봄으로써 Restful 서비스를 위한 <b>스프링</b> 부트의 실제 사용법을 배울 수 있습니다.\n실전 프로젝트 개발에 필요한 Restful 서비스와 <b>스프링</b> 부트의... '},
#   {'title': '박물관 전시기획 마스터하기 (<b>스프링</b>) (전시 개발의 전략)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16418031',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/180/16418031.jpg?type=m1&udate=20200717',
#    'author': '더크 휴트그라프',
#    'price': '12000',
#    'discount': '10800',
#    'publisher': 'TSCP(더쉐이크크리에이티브)',
#    'pubdate': '20200715',
#    'isbn': '1195278942 9791195278947',
#    'description': '한권으로 충분하다! 전시기획 마스터 하기!“오늘날 대부분의 박물관들은 자신들이 더 이상 유물 또는 표본 중심의 기관이 아니라고 인식하고 있다.\n박물관이 아이디어, 경험, 내러티브 중심의 기관이어야 한다는 것이다.”\n\n“박물관의 메시지나 의도를 시각적, 공간적 언어로 해석하여 관람객이 참여하게 하고... '},
#   {'title': '실전! <b>스프링</b> 5를 활용한 리액티브 프로그래밍 (리액티브 애플리케이션 개발부터 클라우드 배포와 모니터링까지)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15045543',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/150/455/15045543.jpg?type=m1&udate=20190613',
#    'author': '올레 도쿠카|이호르 로진스키',
#    'price': '32000',
#    'discount': '28800',
#    'publisher': '위키북스',
#    'pubdate': '20190621',
#    'isbn': '1158391595 9791158391591',
#    'description': '리액티브 시스템을 탐험하고 <b>스프링</b> 부트와 <b>스프링</b> 클라우드를 사용해 효율적인 마이크로 서비스를 만들어 보자!오늘날 기업은 어떤 상황에도 높은... <b>스프링</b> 프레임워크 개발자들은 응답성 높은 시스템을 만들기 위해 리액터 프로젝트를 제안하고 출시했습니다.\n\n이 책은 <b>스프링</b>을 이용한 리액티브... '},
#   {'title': '플루트, 시작해볼까? 1 (<b>스프링</b>) (나의 첫 번째 플루트 교본)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17526668',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/175/266/17526668.jpg?type=m1&udate=20201128',
#    'author': '송화진',
#    'price': '13000',
#    'discount': '11700',
#    'publisher': '음악세계',
#    'pubdate': '20201130',
#    'isbn': '8966855598 9788966855599',
#    'description': '초급과정으로 아이부터 성인까지 플루트를 쉽게 배울 수 있고, 방과 후 교실이나 개인·그룹 레슨, 학원 등에서 활용할 수 있습니다. 배운 것을 바로 적용할 수 있는 다양한 예제곡과 시대 흐름에 맞는 실용적인 실전 연주곡 102곡을 수록하였습니다. 또한, 2·3 파트 음원 QR코드를 수록하여 혼자서도 이... '}]}

# %%
result['display']
# Out:
# 100

# %%
result['items']
# Out:
# [{'title': '올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17193966',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/171/939/17193966.jpg?type=m1&udate=20210324',
#   'author': '올리버 샨 그랜트',
#   'price': '18500',
#   'discount': '16650',
#   'publisher': '비에이블',
#   'pubdate': '20201119',
#   'isbn': '1190931184 9791190931182',
#   'description': '하루 3분, 미국인 선생님과 함께하는 매일 영어 습관\n“원어민 발음에 귀가 열리고, 요즘 영어로 더 유창하게 말하게 된다!”\n외국어 분야 베스트셀러 저자인 올리버쌤이 하루 한 문장씩 1년간 365개 표현을 익힐 수 있는 영어회화 일력을 출간했다. 미국인이 아니면 가르쳐줄 수 없는 원어민들의 생활 속 표현을... '},
#  {'title': '구슬쥬의 시크릿 내신노트 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18122051',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/181/220/18122051.jpg?type=m1&udate=20210322',
#   'author': '구슬쥬',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '메리포핀스',
#   'pubdate': '20210228',
#   'isbn': '119642733X 9791196427337',
#   'description': '그래서 탄생했다. 구슬쥬의 시크릿 내신노트!5만 구독자를 바라보는 공부 유튜버, 구슬쥬가 가장 많이 듣는 말은 “나만 알고 싶은 언니!”라는 말이다. 취미 삼아 시작한 유튜브이지만, 그녀는 영상을 본 사람이라면 ‘나만 알고 싶다’는 생각이 들 정도의 실질적인 ‘공부 꿀팁’만 담아서 영상을 만들어왔고... '},
#  {'title': '2021 전한길 한국사 포켓 암기노트 (<b>스프링</b>) (공무원 시험 대비)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16749210',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/167/492/16749210.jpg?type=m1&udate=20210324',
#   'author': '전한길',
#   'price': '8500',
#   'discount': '',
#   'publisher': '전한길한국사',
#   'pubdate': '20201010',
#   'isbn': '1197133550 9791197133558',
#   'description': '공무원 시험의 시작부터 마무리할 때까지 활용이 가능하며, 수험생들이 시간과 장소에 상관없이 수시로 학습할 수 있도록 휴대하기 간편한 사이즈의 <b>스프링</b> 제본으로 제작되었다. \n\n본서는 중요 키워드를 빈칸 처리하였으며, 사진 및 사료도 풍부하게 수록하였다. 또한, 기출 지문으로 구성한 OX문제로 학습한... '},
#  {'title': '하루 한 장 365 인문학 달력 (<b>스프링</b>) (매일 한 뼘씩 아이 마음이 자라는)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17546229',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/175/462/17546229.jpg?type=m1&udate=20210330',
#   'author': '김종원',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '청림Life',
#   'pubdate': '20201209',
#   'isbn': '1188700723 9791188700721',
#   'description': '15만 부모의 인문교육 멘토, 김종원 작가의 365일 인문학 달력\n매일 한 뼘씩 아이 내면의 힘을 단단하게 키워줄\n인생 문장과 함께 하루를 시작하세요!15만 부모의 찬사를 받은 『아이를 위한 하루 한 줄 인문학』 시리즈와 『부모 인문학 수업』 속 인생 문장을 엄선해 12가지 테마로 엮은 365일 만년 달력.... '},
#  {'title': '2021 에듀윌 공인중개사 부동산세법 체계도 (<b>스프링</b>) (빠른 합격을 위한 세법 압출 끝판왕!, 세법 암기 카드 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17853855',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/178/538/17853855.jpg?type=m1&udate=20210204',
#   'author': '신성룡',
#   'price': '12000',
#   'discount': '10800',
#   'publisher': '에듀윌',
#   'pubdate': '20210201',
#   'isbn': '113600906X 9791136009067',
#   'description': '방대한 부동산세법 핵심을 체계도로 압축 정리!\n빠른 합격을 위한 세법 압축 끝판왕!\n체계를 알아야 합격이 보인다!부동산세법은 내용이 방대하고 암기 내용이 각 세목별로 비슷하기 때문에 수험생들이 학습하기 까다로운 과목입니다. 하지만 체계를 통하여 접근하면 세법은 더 이상 어려운 과목이 아닙니다.... '},
#  {'title': '하루 한 장 초등필수영단어 + 사이트 워드 따라쓰기 (<b>스프링</b>) (QR코드 및 MP3음원제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16684445',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/166/844/16684445.jpg?type=m1&udate=20200920',
#   'author': '이문필',
#   'price': '12500',
#   'discount': '11250',
#   'publisher': '베이직북스',
#   'pubdate': '20200921',
#   'isbn': '1163400467 9791163400462',
#   'description': '분류하여 95일 동안 950개의 단어를 체계적으로 학습할 수 있도록 구성하였습니다.  \n-하루에 10단어 학습(<b>스프링</b>북으로 되어 있어 한 장씩 떼어낼 수 있어요)\n-5일분의 학습이 끝날 때마다 재미있는 퀴즈로 복습\n-바로바로 원어민의 음성을 들을 수 있는 큐알코드 수록\n-영어 발음 기호와 한글 발음 동시 수록'},
#  {'title': '초등교과 어휘왕 가로세로 낱말퍼즐(고급)(<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18830241',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/188/302/18830241.jpg?type=m1&udate=20210327',
#   'author': '베이직콘텐츠연구소',
#   'price': '10800',
#   'discount': '8640',
#   'publisher': '키즈프렌즈',
#   'pubdate': '20210405',
#   'isbn': '9565330088 8809565330087',
#   'description': '초등 어휘력이 공부력이다!\n초등교과서 필수 어휘 4천여 개 수록《초등교과 어휘왕 가로세로 낱말 퍼즐》은 초등학교 전 과목 교과서와 일상생활에서 초등학생들이 꼭 알아야 할 낱말들을 골라 퍼즐로 만들었어요. 모르는 단어도 앞뒤 단어와 예시문을 통해 낱말을 유추하고 놀이하듯 빈칸을 채우면서 뜻을 알게... '},
#  {'title': '초등교과 어휘왕 가로세로 낱말퍼즐 : 중급 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17982776',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/179/827/17982776.jpg?type=m1&udate=20210225',
#   'author': '베이직콘텐츠연구소',
#   'price': '10800',
#   'discount': '8640',
#   'publisher': '키즈프렌즈',
#   'pubdate': '20210225',
#   'isbn': '956533007X 8809565330070',
#   'description': '초등 어휘력이 공부력이다!\n초등교과서 필수 어휘 4천여 개 수록《초등교과 어휘왕 가로세로 낱말 퍼즐》은 초등학교 전 과목 교과서와 일상생활에서 초등학생들이 꼭 알아야 할 낱말들을 골라 퍼즐로 만들었어요. 모르는 단어도 앞뒤 단어와 예시문을 통해 낱말을 유추하고 놀이하듯 빈칸을 채우면서 뜻을 알게... '},
#  {'title': '[개정판] 피아노로 연주하는 디즈니 OST 베스트 Original Ver. (<b>스프링</b>) (체르니 30 이상 난이도)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16270696',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/706/16270696.jpg?type=m1&udate=20200222',
#   'author': '정유리|콘텐츠기획개발부',
#   'price': '18000',
#   'discount': '16200',
#   'publisher': '삼호뮤직',
#   'pubdate': '20200228',
#   'isbn': '8932637717 9788932637716',
#   'description': "꿈과 환상을 전해줄 디즈니의 선물!\n피아노로 연주하는 디즈니 OST 베스트!디즈니만의 색으로 남녀노소, 동서고금을 막론하고 감동을 전해주는 디즈니의 음악! 『피아노로 연주하는 디즈니 OST 베스트 ORIGINAL VER.』 개정판. 피아노로 연주하는 디즈니 OST 베스트'는 그런 디즈니 작품들의 오리지널 사운드... "},
#  {'title': '피지컬갤러리의 하루 5분 내 몸 관리법(<b>스프링</b>) (대한민국 1등 건강 유튜브 200만 채널)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16491909',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/919/16491909.jpg?type=m1&udate=20201007',
#   'author': '라이프에이드',
#   'price': '19800',
#   'discount': '17820',
#   'publisher': '시간과공간사',
#   'pubdate': '20200910',
#   'isbn': '119081806X 9791190818063',
#   'description': '독서대 기능이 있는 특허 받은 제본은 특히 자랑할 만하다. 책상에 세워두고 멀찍이 앉아도 눈에 들어오도록 활자를 키웠다. 책장이 쉽게 넘어가는 <b>스프링</b>제본을 추가했다. 고개를 숙일 필요가 없고 멀리 떨어져 볼 수 있어서 눈 건강, 척추 건강에도 좋은 책이다.'},
#  {'title': '<b>스프링</b>북 교과서 가로세로 낱말퍼즐 : 초급 (<b>스프링</b>) (초등학생 필수 어휘 총출동!)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16363381',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/633/16363381.jpg?type=m1&udate=20210301',
#   'author': '김수웅',
#   'price': '9800',
#   'discount': '8820',
#   'publisher': '시간과공간사',
#   'pubdate': '20200630',
#   'isbn': '1190818019 9791190818018',
#   'description': '시리즈 모두 고급스러운 <b>스프링</b>제본으로 아이들이 쉽게 책장을 넘기고 필기할 수 있도록 도왔습니다. 모든 공부의 기본은 어휘력이라는 말처럼, 우리 아이들이 이 책을 놀이 삼아 풀면서 어휘력을 향상시키고 탄탄한 학업의 기초를 쌓기를 바라는 저자의 진심이 온전히 전해지기를 바랍니다.'},
#  {'title': '피아노로 연주하는 디즈니 OST 베스트 Easy Ver.(개정판)(<b>스프링</b>) (체르니 100~30 난이도)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16270812',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/708/16270812.jpg?type=m1&udate=20200310',
#   'author': '정유리|콘텐츠기획개발부',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '삼호뮤직',
#   'pubdate': '20200228',
#   'isbn': '8932637709 9788932637709',
#   'description': "꿈과 환상을 전해줄 디즈니의 선물!\n피아노로 연주하는 디즈니 OST 베스트!디즈니만의 색으로 남녀노소, 동서고금을 막론하고 감동을 전해주는 디즈니의 음악! '피아노로 연주하는 디즈니 OST 베스트[개정판]'은 그런 디즈니 작품들의 오리지널 사운드 트랙들을 모아, 피아노 솔로 연주곡으로 쉽게 편곡하여... "},
#  {'title': '보카바이블 4.0 데스크북(+미니단어장)(<b>스프링</b>) (공무원, 편입, 토플, 텝스, SAT, GRE 대비서)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16122710',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/161/227/16122710.jpg?type=m1&udate=20200129',
#   'author': '허민',
#   'price': '17500',
#   'discount': '15750',
#   'publisher': '스텝업',
#   'pubdate': '20200108',
#   'isbn': '8994553118 9788994553115',
#   'description': '보카바이블 4.0 데스크북(+미니단어장)은 영어단어를 좀 더 자주 볼 수 있도록 하기 위해 공부하는 책상 위에 올려두고 수시로 보는 캘린더형식으로 만들어진 영어단어장입니다. 또한 점심시간이나 대중교통으로 이동하는 시간에 휴대하면서 짬짬이 볼 수 있도록 미니단어장도 함께 제공됩니다. 독서실 책상위엔... '},
#  {'title': '<b>스프링</b>북 교과서 가로세로 낱말퍼즐 중급(<b>스프링</b>) (초등학생 필수 어휘 총출동)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16404759',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/047/16404759.jpg?type=m1&udate=20200707',
#   'author': '김수웅',
#   'price': '9800',
#   'discount': '8820',
#   'publisher': '시간과공간사',
#   'pubdate': '20200730',
#   'isbn': '1190818043 9791190818049',
#   'description': '시리즈 모두 고급스러운 <b>스프링</b>제본으로 아이들이 쉽게 책장을 넘기고 필기할 수 있도록 도왔습니다. 모든 공부의 기본은 어휘력이라는 말처럼, 우리 아이들이 이 책을 놀이 삼아 풀면서 어휘력을 향상시키고 탄탄한 학업의 기초를 쌓기를 바라는 저자의 진심이 온전히 전해지기를 바랍니다.'},
#  {'title': '<b>스프링</b> 부트와 AWS로 혼자 구현하는 웹 서비스 (인텔리제이, JPA, JUnit 테스트, 그레이들, 소셜 로그인, AWS 인프라로 무중단 배포까지)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15871738',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/158/717/15871738.jpg?type=m1&udate=20191128',
#   'author': '이동욱',
#   'price': '22000',
#   'discount': '19800',
#   'publisher': '프리렉',
#   'pubdate': '20191129',
#   'isbn': '8965402603 9788965402602',
#   'description': '경험이 실력이 되는 순간!이 책은 제목 그대로 <b>스프링</b> 부트와 AWS로 웹 서비스를 구현합니다. JPA와 JUNIT 테스트, 그레이들, 머스테치, <b>스프링</b> 시큐리티를... 이렇게 점진적으로 <b>스프링</b> 부트 프로젝트를 개선해서 배포 자동화하고 무중단 배포까지 경험합니다. 실무 현장에서의 노하우와 테스트 방법, 객체지향... '},
#  {'title': '혜민 스님의 따뜻한 응원(2020)(<b>스프링</b>) (365일 마음 달력)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15910263',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/159/102/15910263.jpg?type=m1&udate=20200123',
#   'author': '혜민',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '수오서재',
#   'pubdate': '20191126',
#   'isbn': '1190382067 9791190382069',
#   'description': '힘이 되고 위안이 되는, 혜민 스님 잠언을 365일 만나세요\n두고두고 보는 혜민 스님 만년 달력!많은 이에게 용기와 지혜, 고요의 시간을 선물한 혜민 스님의 잠언을 엮은 365일 달력. SNS 3백만 팔로워들의 아침을 열어주는 〈혜민 스님의 따뜻한 응원〉을 책상이나 머리맡에 두고 한 장 한 장 넘기며 하루를... '},
#  {'title': '스도쿠x로직아트(초급/중급)(<b>스프링</b>) (뇌과학이 입증한 최고의 두뇌 게임!)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16375653',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/756/16375653.jpg?type=m1&udate=20200626',
#   'author': '브레이니 퍼즐 랩',
#   'price': '8800',
#   'discount': '7920',
#   'publisher': '시간과공간사',
#   'pubdate': '20200710',
#   'isbn': '1190818035 9791190818032',
#   'description': '●스도쿠와 로직아트 둘 다 수학적 원리에 기반해 만들어졌다. 연령, 학력, 성별 상관없이 재밌게 풀다 보면 논리력, 수리력, 추리력이 저절로 발달하게 된다.\n●<b>스프링</b>이 겉면에 드러나지 않는 고급스러운 <b>스프링</b>제본으로 사용성과 품질을 높였다. \n●고급/고수편도 곧 출시될 예정이다.'},
#  {'title': '네이티브만 아는 진짜 영어 100(<b>스프링</b>) (수많은 구독자가 열광하는 문법 밖 영어회화)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16328832',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/288/16328832.jpg?type=m1&udate=20210204',
#   'author': '구슬쌤',
#   'price': '13500',
#   'discount': '12150',
#   'publisher': '시원스쿨닷컴',
#   'pubdate': '20200416',
#   'isbn': '1161503358 9791161503356',
#   'description': '문법상 틀린 건 아닌데 어색했던 영어,\n영어 교육 유튜버이자 영어회화 전문 강사 ‘구슬쌤’이 자연스럽게 만들어 줍니다!“점심 먹자.”고 할 땐 EAT보단 GRAB!\n‘알려 달라’고 할 땐 TELL ME보단 LET ME KNOW!\n감기 걸려 병원에 갈 땐 HOSPITAL보단 CLINIC!\n\n문법으로 해결되지 않는 영어 자연스럽게 말하는... '},
#  {'title': '2021 이공자 ITQ 파워포인트 2016 (<b>스프링</b>) (최신 자동채점프로그램 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18125411',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/181/254/18125411.jpg?type=m1&udate=20210402',
#   'author': 'KIE 기획연구실',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '아소미디어(아카데미소프트)',
#   'pubdate': '20210225',
#   'isbn': '8984550205 9788984550209',
#   'description': '- 2020년 7월 정기시험부터 새롭게 변경된 시험유형을 모두 반영한 최신교재!!\n- 기출 예상문제 완벽대비!!\n- 최신 자동채점프로그램 무료 제공!!'},
#  {'title': '뷰티 일러스트레이션 워크북 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18866733',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/188/667/18866733.jpg?type=m1&udate=20210405',
#   'author': '오수나|김유경|박혜원|정혜영|조애라',
#   'price': '23000',
#   'discount': '22310',
#   'publisher': '구민사',
#   'pubdate': '20210330',
#   'isbn': '1158139136 9791158139131',
#   'description': 'How to illustration! 뷰티 일러스트레이션 워크북은 뷰티 전공자들의 뷰티 일러스트레이션을 위한 입문서로 기초 드로잉 과정을 중심으로 집필되었습니다. 많은 것들이 디지털화 되어가고 있고 일러스트의 방식도 다양화되어 가고 있으나 뷰티 일러스트레이션 워크북은 모든 작업이 드로잉에 기반하고 있음을 잊지... '},
#  {'title': '우리들의 예쁜 손글씨(손글씨 따라쓰기 교본 1)(<b>스프링</b>) (일기체)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16240534',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/405/16240534.jpg?type=m1&udate=20200207',
#   'author': '김정은|김지향',
#   'price': '12000',
#   'discount': '10800',
#   'publisher': '북코디',
#   'pubdate': '20200205',
#   'isbn': '1195994958 9791195994953',
#   'description': '일상의 기록을 위해 ‘일기체’를 추천합니다우리는 매일매일 기록을 하면서 살고 있습니다.\n\n누군가에게 짧은 메모를 남기고,\n사야 하거나 사고 싶은 것들을 써 두고,\n나의 마음을 전하고 싶어 또박또박 손편지를 쓰고,\n하루를 정리하면서 나에 대한 얘기로 일기를 써 내려가는 등\n하루종일 우리는 무엇인가를... '},
#  {'title': '<b>스프링</b>북 어린이 스도쿠 2 (고급.고수)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14103819',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/141/038/14103819.jpg?type=m1&udate=20181110',
#   'author': '브레이니 퍼즐 랩',
#   'price': '7700',
#   'discount': '6930',
#   'publisher': '시간과공간사',
#   'pubdate': '20181101',
#   'isbn': '8971422645 9788971422649',
#   'description': '어린이의 눈높이에 맞춘 <b>스프링</b>북 어린이 스도쿠!하나씩 풀다 보면 논리력 / 집중력 / 추리력 강화!... <b>스프링</b> 제본이라 완전하게 펼쳐지고 반으로 접을 수도 있습니다.? 둥근 모서리는 손을 보호해줘요~4X4... 편하게 <b>스프링</b> 제본으로 만들었습니다. 둥글게 라운드 처리된 모서리는 아이들의 손을 보호해줘요... '},
#  {'title': '<b>스프링</b>북 어린이 스도쿠 1 (초급.중급)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14103818',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/141/038/14103818.jpg?type=m1&udate=20181031',
#   'author': '브레이니 퍼즐 랩',
#   'price': '7700',
#   'discount': '6930',
#   'publisher': '시간과공간사',
#   'pubdate': '20181101',
#   'isbn': '8971422637 9788971422632',
#   'description': '어린이의 눈높이에 맞춘 <b>스프링</b>북 어린이 스도쿠!하나씩 풀다 보면 논리력 / 집중력 / 추리력 강화!... <b>스프링</b> 제본이라 완전하게 펼쳐지고 반으로 접을 수도 있습니다.? 둥근 모서리는 손을 보호해줘요~4X4... 편하게 <b>스프링</b> 제본으로 만들었습니다. 둥글게 라운드 처리된 모서리는 아이들의 손을 보호해줘요... '},
#  {'title': '신비아파트 하루 한 장 : 속담 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18215363',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/182/153/18215363.jpg?type=m1&udate=20210409',
#   'author': '서울문화사 편집부',
#   'price': '18000',
#   'discount': '14400',
#   'publisher': '서울문화사',
#   'pubdate': '20210330',
#   'isbn': '9170011249 8809170011241',
#   'description': '신비아파트 친구들과 함께\n신나게 배우고 써 보는 우리 속담 100!〈신비아파트 속담 사전〉을 쓰기 책으로 재구성!\n〈신비아파트 하루 한 장 속담〉은 〈신비아파트 고스트볼X의 탄생 속담 사전〉에서 다양한 우리 속담 중에서 100가지를 골라, 쓰기 책으로 구성하였습니다. 이 책에서는 속담 내용은 기존의... '},
#  {'title': '읽기유창성 및 읽기이해 프로그램 교사용 (<b>스프링</b>) (학령기 아동을 위한)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18898177',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/188/981/18898177.jpg?type=m1&udate=20210409',
#   'author': '김애화|김의정',
#   'price': '25000',
#   'discount': '22500',
#   'publisher': '학지사',
#   'pubdate': '20210330',
#   'isbn': '8999723771 9788999723773',
#   'description': ''},
#  {'title': '나 혼자 기타 친다 비기너 (<b>스프링</b>) (정완의 기타 독학)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18214730',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/182/147/18214730.jpg?type=m1&udate=20210316',
#   'author': '최정완',
#   'price': '17000',
#   'discount': '15300',
#   'publisher': '삼호ETM',
#   'pubdate': '20210320',
#   'isbn': '8967212569 9788967212568',
#   'description': '『나 혼자 기타 친다 비기너』는 기타를 독학으로 처음 시작하는 사람들을 위하여 상세하고 체계적인 커리큘럼으로 이루어져 있는 친절한 독학서입니다. 기타 필수곡이자 기타로 가장 치고 싶은 최고의 명곡을 다수 수록하였고, Q&A와 각 챕터별 연습 문제 풀이까지 다양한 내용으로 구성되어 있습니다.... '},
#  {'title': '코드로 배우는 <b>스프링</b> 부트 웹 프로젝트 (현업 개발을 위한 단계별 실습서(동영상 강의 제공))',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17597624',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/175/976/17597624.jpg?type=m1&udate=20201223',
#   'author': '구멍가게 코딩단',
#   'price': '34000',
#   'discount': '30600',
#   'publisher': '남가람북스',
#   'pubdate': '20201210',
#   'isbn': '1189184079 9791189184070',
#   'description': '‘<b>스프링</b> 프레임워크를 좀 더 간단히 사용할 수는 없을까?’\n이 책의 시작은 위의 질문에서 시작합니다. 좀 더 빠르게 개발하면서 <b>스프링</b> 프레임워크의 모든 기능을 활용할 수 있는 <b>스프링</b> 부트는 INTELLIJ나 이클립스, VS CODE 등 개발 도구들의 지원 역시 활발합니다. <b>스프링</b> 부트의 경우 자동 설정... '},
#  {'title': 'ITQ엑셀 2016(2020)(이공자)(<b>스프링</b>) (자동채점프로그램 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16360122',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/601/16360122.jpg?type=m1&udate=20200526',
#   'author': 'KIE 기획연구실',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '아카데미소프트',
#   'pubdate': '20200511',
#   'isbn': '8984550159 9788984550155',
#   'description': '- 새롭게 변경된 시험유형을 모두 반영한 최신교재!\n- 최신 자동채점프로그램 무료 제공!\n\n● 출제유형 완전정복하기 \n최근에 출제된 ITQ 시험의 출제유형을 분석하여 새롭게 변경된 내용과 시험에 자주 출제되는 부분을 단계별로 체크하고 작성할 수 있도록 구성하였습니다. \n● 유형정복 모의고사\n출제유형... '},
#  {'title': '신비아파트 하루 한 장 : 한자 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18215370',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/182/153/18215370.jpg?type=m1&udate=20210405',
#   'author': '서울문화사 편집부',
#   'price': '18000',
#   'discount': '14400',
#   'publisher': '서울문화사',
#   'pubdate': '20210323',
#   'isbn': '9170011206 8809170011203',
#   'description': '신비아파트 친구들과 함께\n신나게 배우고 써 보는 한자 150자!신비아파트 한자 사전〉을 쓰기 책으로 재구성!\n〈신비아파트 하루 한 장 한자〉는 〈신비아파트 고스트볼X의 탄생 한자 사전〉에서 수록되었던 8~7급 한자를 비롯하여, 사전에 수록하지 못한 나머지 8~7급 한자를 모두 담았습니다. 이 책에서는... '},
#  {'title': '<b>스프링</b> 인 액션(5판) (<b>스프링</b> 5의 강력한 기능과 생산성을 활용한 웹 애플리케이션 개발)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16348386',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/483/16348386.jpg?type=m1&udate=20201017',
#   'author': '크레이그 월즈',
#   'price': '35000',
#   'discount': '31500',
#   'publisher': '제이펍',
#   'pubdate': '20200514',
#   'isbn': '1190665182 9791190665186',
#   'description': '리액티브 프로그래밍 지원을 강화한 <b>스프링</b> 5의 모든 것을 탐구한다!이 책에서는 <b>스프링</b> 5와 <b>스프링</b> 부트 2를 사용해서 애플리케이션을 개발하는 데 필요한 여러  핵심 기능을 알려줍니다. <b>스프링</b> 5에서는 특히 새로운 리액티브 웹 프레임워크인 WEBFLUX를 중점적으로 다룹니다. 개발자들은 더 쉽고 확장성이... '},
#  {'title': '또래 퀴즈: 상식 퀴즈 백과(<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18985011',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/189/850/18985011.jpg?type=m1&udate=20210416',
#   'author': '강영훈',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '이젠교육',
#   'pubdate': '20210415',
#   'isbn': '1197068457 9791197068454',
#   'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 상식 퀴즈 백과≫에는 일반, 직업, 세계, 한국, 인물, 동물, 공룡 등에 관한 다양하고 재미있는 상식 퀴즈가... '},
#  {'title': 'ITQ 파워포인트 2016(2020)(이공자)(<b>스프링</b>) (최신 자동채점프로그램 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16283043',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/830/16283043.jpg?type=m1&udate=20210313',
#   'author': 'KIE 기획연구실',
#   'price': '16000',
#   'discount': '',
#   'publisher': '아카데미소프트',
#   'pubdate': '20200226',
#   'isbn': '8984550043 9788984550049',
#   'description': '최근에 출제된 ITQ 시험의 출제유형을 분석하여 새롭게 변경된 내용과 시험에 자주 출제되는 부분을 단계별로 체크하고 작성할 수 있도록 구성하였다. 출제유형 완전정복에서 학습한 내용을 바탕으로 시험에 대한 전반적인 유형을 파악하고 실력을 향상시킬 수 있도록 모의고사를 구성하였으며, 2020년 7월... '},
#  {'title': '흑박물관 고스트 앤드 레이디 상.하 박스 세트 - 전2권 (흑박물관 <b>스프링</b>갈드 포함)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18862291',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/188/622/18862291.jpg?type=m1&udate=20210410',
#   'author': '후지타 카즈히로',
#   'price': '27000',
#   'discount': '24300',
#   'publisher': '학산문화사(만화)',
#   'pubdate': '20210330',
#   'isbn': '1134879814 9791134879815',
#   'description': '서커스〉, 〈쌍망정은 부숴야 한다〉 등으로 우리에게 잘 알려진 작가 \n후지타 카즈히로의 기발한 상상력으로 그린 도시괴담 시리즈의 2탄이다.\n1탄 〈<b>스프링</b>갈드〉와 함께 박스판으로도 만나볼 수 있는 이번 기획은 작가의\n팬은 물론, 고딕풍의 배경을 좋아하는 독자라면 한 번쯤 꼭 소장하게 될 한권이다.'},
#  {'title': '<b>스프링</b>북 교과서 가로세로 낱말퍼즐(고급)(<b>스프링</b>) (초등학생 필수 어휘 총출동!)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16853362',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/168/533/16853362.jpg?type=m1&udate=20201029',
#   'author': '김수웅',
#   'price': '9800',
#   'discount': '8820',
#   'publisher': '시간과공간사',
#   'pubdate': '20201130',
#   'isbn': '1190818086 9791190818087',
#   'description': '시리즈 모두 고급스러운 <b>스프링</b>제본으로 아이들이 쉽게 책장을 넘기고 필기할 수 있도록 도왔습니다. 모든 공부의 기본은 어휘력이라는 말처럼, 우리 아이들이 이 책을 놀이 삼아 풀면서 어휘력을 향상시키고 탄탄한 학업의 기초를 쌓기를 바라는 저자의 진심이 온전히 전해지기를 바랍니다.'},
#  {'title': '또래퀴즈: 사회 문화 퀴즈백과(<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18985010',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/189/850/18985010.jpg?type=m1&udate=20210416',
#   'author': '최인수',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '이젠교육',
#   'pubdate': '20210415',
#   'isbn': '1197068449 9791197068447',
#   'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 사회 문화 퀴즈 백과≫에는 사회.문화와 관련한 한국사, 세계사, 경제, 한국지리, 문화 및 문화재, 상식... '},
#  {'title': '아이유 베스트 피아노 스코어(<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16215057',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/150/16215057.jpg?type=m1&udate=20200207',
#   'author': '라몽 피아노(김정현)',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '음악세계',
#   'pubdate': '20200205',
#   'isbn': '8966855407 9788966855407',
#   'description': '대한민국 최고의 여성 싱어송라이터 아이유의 베스트 25곡을 마피아(마음만은 피아니스트) 컴퍼니 전속 편곡자이자 인기 피아노 유튜버인 라몽 피아노가 편곡한 피아노 악보집입니다. 최신곡 ‘첫 겨울이니까’와 최근 앨범 「LOVE POEM」의 전곡, 그리고 그동안 발매된 아이유 앨범의 모든 타이틀 곡을... '},
#  {'title': '<b>스프링</b>으로 하는 마이크로서비스 구축 (<b>스프링</b> 부트와 <b>스프링</b> 클라우드를 이용한 도커)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17469720',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/174/697/17469720.jpg?type=m1&udate=20201211',
#   'author': '매그너스 라슨',
#   'price': '40000',
#   'discount': '36000',
#   'publisher': '에이콘출판',
#   'pubdate': '20201130',
#   'isbn': '1161754679 9791161754673',
#   'description': '★ 요약 ★\n\n기존 일체형 애플리케이션을 마이크로서비스로 나누고 온프레미스나 클라우드로 배포하려는 자바, <b>스프링</b> 개발자와 아키텍트를 위한 책이다. \n<b>스프링</b> 부트, <b>스프링</b> 클라우드와 도커, 쿠버네티스, 이스티오, EFK 스택, 프로메테우스, 그라파나 등의 오픈 소스 도구를 조합해 마이크로서비스를... '},
#  {'title': '깜놀 히브리어 1(<b>스프링</b>) (재미있게 배우는 그림 연상 히브리어)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16417228',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/172/16417228.jpg?type=m1&udate=20200725',
#   'author': '이요엘',
#   'price': '30000',
#   'discount': '27000',
#   'publisher': '두란노서원',
#   'pubdate': '20200715',
#   'isbn': '8953137918 9788953137912',
#   'description': '머리에서 증발되는 히브리어는 이제 안녕~\n깜놀 그림 암송법으로 히브리어가 술술히브리어를 두 번이나 낙제한 경험이 있는 저자가 만든 히브리어 교재\n저자인 이요엘 교수는 히브리어를 두 번이나 낙제했다고 한다. 괴로워하며 눈물을 흘리고 한참을 기도했는데, 하나님은 이런 마음을 주셨다.\n‘단어를 먼저... '},
#  {'title': '헤븐피아노 CCM 워십악보 2 (<b>스프링</b>) (마커스워십, 어노인팅, 위러브, 제이워십, 찬미워십 등)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16386299',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/862/16386299.jpg?type=m1&udate=20201012',
#   'author': '김선희',
#   'price': '21000',
#   'discount': '18900',
#   'publisher': '분명한소리',
#   'pubdate': '20200622',
#   'isbn': '1197025103 9791197025105',
#   'description': '▶ 피아노 혼자 연주할 때를 고려하여 편곡하였습니다.\n▶ 다른 악기의 역할을 표현하는 방법도 담았습니다.\n▶ <b>스프링</b> 북으로 편하게 연습하실 수 있습니다.\n▶ 모든 곡은 큐알(Q.R) 코드가 있어, 연주 영상을 확인할 수 있습니다.\n▶ 모든 곡에 헤븐피아노 연주 팁(TIP)을 담았습니다.'},
#  {'title': '헤븐피아노 실전 반주악보 6 (<b>스프링</b>) (기본 코드)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17525461',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/175/254/17525461.jpg?type=m1&udate=20201203',
#   'author': '김선희|김현우',
#   'price': '21000',
#   'discount': '18900',
#   'publisher': '분명한소리',
#   'pubdate': '20201202',
#   'isbn': '1197025111 9791197025112',
#   'description': '▶ PART.1 기본 코드 - 정확한 보이싱으로 깔끔하게 연주하기\n▶ PART.2 실전 반주 CCM 10곡과 헤븐피아노 연주 팁(TIP)\n▶ PART.3 찬송가 리하모니제이션 10곡을 여러 버전으로 담았습니다.\n▶ <b>스프링</b> 북으로 편하게 연습하실 수 있습니다.\n▶ 모든 곡은 큐알(Q.R) 코드가 있어, 연주 영상을 확인할 수 있습니다.'},
#  {'title': 'ITQ 한글 ver.2010(이기적)(<b>스프링</b>) (최신 출제기준 분석 + 동영상 강의 무료 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16430071',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/300/16430071.jpg?type=m1&udate=20200729',
#   'author': '영진정보연구소',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '영진닷컴',
#   'pubdate': '20200720',
#   'isbn': '8931463103 9788931463101',
#   'description': '본 도서는 ITQ 한글 시험 경향을 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서입니다. 한글 VER.2010을 기준으로 작성되었으며, 2020년 7월 공식 시험버전이 2016으로 변경되었지만 2021년까지 2010버전도 응시가 가능하므로 상황에 맞게 선택하실 수 있습니다.\n꼼꼼이론과 유형을 확인하는... '},
#  {'title': 'JLPT N3 일본어 단어 쓰기 노트(<b>스프링</b>) (기적의 쓰기 학습법으로 공부하는)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17909741',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/179/097/17909741.jpg?type=m1&udate=20210303',
#   'author': '박다진',
#   'price': '13800',
#   'discount': '12420',
#   'publisher': '세나북스',
#   'pubdate': '20210125',
#   'isbn': '118731675X 9791187316756',
#   'description': '머리와 손이 기억하는 ‘기적의 쓰기 학습법’으로\n일본어 기본 단어를 마스터하자!\n출제 빈도 높은 JLPT N3 단어 1,024개 수록!\nJLPT(일본어능력시험) N3에서 반드시 알아야 하고 실생활에서 자주 사용하는 일본어 필수 단어와 한자를 관련 문장을 직접 쓰면서 익힐 수 있도록 구성하였습니다. 단어만 학습하는... '},
#  {'title': '<b>스프링</b>북 스도쿠 1 (초급 중급)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13069530',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/130/695/13069530.jpg?type=m1&udate=20180105',
#   'author': '시간과공간사 편집부',
#   'price': '7500',
#   'discount': '6750',
#   'publisher': '시간과공간사',
#   'pubdate': '20180108',
#   'isbn': '8971429917 9788971429914',
#   'description': '머리는 쓰면 쓸수록 두뇌가 깨어난다!&#x0D;스마트폰에 익숙한 현대인의 두뇌회전에 도움을!&#x0D;&#x0D;요즘 스마트폰을 사용하지 않는 사람을 보기가 어려울 정도로 우리는 스마트폰 사용률이 높다. 그러다 보니 하루 일과를 스마트폰과 함께 하는 시간이 대부분이다. 오죽하면 스마트폰 제한 앱까지 나왔을까... '},
#  {'title': '실전! <b>스프링</b> 5와 Vue.js 2로 시작하는 모던 웹 애플리케이션 개발 (<b>스프링</b> 부트와 Vuex를 활용한 실습 중심의 풀스택 웹 애플리케이션 개발)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16113469',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/161/134/16113469.jpg?type=m1&udate=20200114',
#   'author': '제임스 J. 예 저|김현만,권봉혁,변준석',
#   'price': '36000',
#   'discount': '32400',
#   'publisher': '위키북스',
#   'pubdate': '20200121',
#   'isbn': '1158391854 9791158391850',
#   'description': '프런트엔드와 백엔드 웹 개발에서 <b>스프링</b>과 VUE를 사용해 효율성을 높이자!이 책은 실용적인 접근법으로 풀스택 웹 개발자가 되는 데 도움을 줍니다.... 이 책을 통해 웹 애플리케이션을 개발하는 방법을 배우면서 <b>스프링</b> 5와 VUE.JS 2에 익숙해질 것입니다. 초기 구조화부터 전체 배포까지, VUE.JS 2와 <b>스프링</b> 5를... '},
#  {'title': 'ACL 김중근 형사소송법 서브노트 (<b>스프링</b>) (경찰채용 / 경찰간부 / 경찰승진 / 법원직 / 검찰직 / 해경 / 해경간부 / 교정직 / 소방직 / 출입국관리직)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16686416',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/166/864/16686416.jpg?type=m1&udate=20201020',
#   'author': '김중근',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '에이씨엘커뮤니케이션',
#   'pubdate': '20200914',
#   'isbn': '1165230992 9791165230999',
#   'description': '〈이 책의 특징〉\n\n판서 내용 완벽 정리\n중요 기출과 조문을 OX 문제로 수록[100% 지문 교체]\n최신 개정법 반영[통신비밀보호법]\n\n[부록]\n두문자 암기법, 주의할 조문, 숫자 정리\n시험에 필요한 주옥같은 멘트\n할 수 있다/하여야 한다'},
#  {'title': '벨라앤루카스 포핸즈 연주곡집 (Original Ver.) (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16120927',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/161/209/16120927.jpg?type=m1&udate=20200115',
#   'author': '벨라 앤 루카스',
#   'price': '18000',
#   'discount': '16200',
#   'publisher': '삼호ETM',
#   'pubdate': '20200122',
#   'isbn': '8967212003 9788967212001',
#   'description': '최신 가요, 영화 및 드라마 OST를 포핸즈 피아노로 새롭게 재해석하여 연주하는 벨라앤루카스!피아노 듀엣 부문 구독자 44만 명! 유튜브에서 가장 핫한 듀엣 피아니스트 ‘벨라앤루카스’의 포핸즈 연주곡집입니다. 최신 드라마, 영화 OST부터 케이팝, 클래식까지! 둘이 연주해서 더 좋은 포핸즈 커버를... '},
#  {'title': '최진우 독한국사 독심술 찐[眞] (<b>스프링</b>) (독한국사 심플한 이론정리 술술 읽히는 요약서)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16626683',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/166/266/16626683.jpg?type=m1&udate=20200826',
#   'author': '최진우',
#   'price': '22000',
#   'discount': '19800',
#   'publisher': '더나은',
#   'pubdate': '20201007',
#   'isbn': '1190837129 9791190837125',
#   'description': '독한국사 심플한 이론정리 술술 읽히는 요약서\n\n1. 빈틈없이 정리한 완전무결 진짜 한국사 요약서\n2. 이 한권으로 이론(기본+심화) 정리와 암기를 한번에 완성\n3. 한 눈에 들어오는 체계적인 시대사 도표\n4. 헷갈리는 한국사 이론을 테마별 분류로 쉽게 이해\n5. 최신 공무원 기출 + 8종 고등 교과서 내용 완벽 반영... '},
#  {'title': '2021 손에 잡히는 꼼꼼한 의학이론 요약집 (<b>스프링</b>) (신체손해사정사 2차 의학이론)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18862352',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/188/623/18862352.jpg?type=m1&udate=20210330',
#   'author': '정혜심',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '고시아카데미(한국금융보험방송)',
#   'pubdate': '20210325',
#   'isbn': '8966311962 9788966311965',
#   'description': ''},
#  {'title': '코드로 배우는 <b>스프링</b> 웹 프로젝트 (현업 개발을 위한 단계별 실습서)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13993776',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/139/937/13993776.jpg?type=m1&udate=20210128',
#   'author': '구멍가게 코딩단',
#   'price': '38000',
#   'discount': '34200',
#   'publisher': '남가람북스',
#   'pubdate': '20180913',
#   'isbn': '118918401X 9791189184018',
#   'description': '이 책은 SPRING FRAMEWORK(이하 <b>스프링</b>)를 사용해서 말 그대로 ‘웹 프로젝트’를 어떻게 진행하는지를 설명하는 책입니다. 웹 프로젝트라고 거창하게 표현하지만, 좀 더 구체적으로는 <b>스프링</b>으로 웹... 독자]\n<b>스프링</b>으로 웹 프로젝트를 진행하기 위해서는 다음과 같은 선행학습이 필요합니다. \n* JAVA 언어에... '},
#  {'title': '마이 스위트 카페 스티커 컬러링북 (<b>스프링</b>) + 아르누보 36색 색연필 세트',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16388820',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/888/16388820.jpg?type=m1&udate=20200624',
#   'author': '이수현',
#   'price': '30000',
#   'discount': '10000',
#   'publisher': '아르누보',
#   'pubdate': '20200528',
#   'isbn': '9474875650 8809474875655',
#   'description': '당신이 꿈꾸는 달콤한 쉼터는 어떤 색인가요?\n스위트 카페의 감성을 담은 컬러링 스티커에\n나만의 색을 입혀 보세요.바쁜 일상에 지친 당신에게 《마이 스위트 카페 스티커 컬러링북》이 맛있는 행복을 가득 담은 300개의 다양한 컬러링 스티커를 선물합니다. \n감미로운 커피 향기를 따라가면 발견할 수 있는... '},
#  {'title': '뚝딱뚝딱 입체 종이접기 2 (<b>스프링</b>) (동물, 로봇)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=19007739',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/190/077/19007739.jpg?type=m1&udate=20210422',
#   'author': '이지숙',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '스쿨존(굿인포메이션)',
#   'pubdate': '20210415',
#   'isbn': '1197415114 9791197415111',
#   'description': '놀이와 두뇌계발, 두 마리 토끼를 동시에!!!\n\n똥손 엄마 도전!\n만들기 잼병 아빠도 함께!\n산만한 우리아이와 함께 할 입체 종이접기!\n\n아이 얼굴만 쳐다보고 있을 수도 없고,\n같이 놀아주려 해도 체력이 따라주지 않고,\n마냥 유튜브만 틀어줄 수는 없고...\n함께 노는 것도 고민해야 해?!?\n\n얼굴만 쳐다보고 있어도... '},
#  {'title': '뚝딱뚝딱 입체 종이접기 3 (<b>스프링</b>) (탈것(하늘.물), 공룡, 집)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=19007734',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/190/077/19007734.jpg?type=m1&udate=20210422',
#   'author': '이지숙',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '스쿨존(굿인포메이션)',
#   'pubdate': '20210415',
#   'isbn': '1197415122 9791197415128',
#   'description': '놀이와 두뇌계발, 두 마리 토끼를 동시에!!!\n\n똥손 엄마 도전!\n만들기 잼병 아빠도 함께!\n산만한 우리아이와 함께 할 입체 종이접기!\n\n아이 얼굴만 쳐다보고 있을 수도 없고,\n같이 놀아주려 해도 체력이 따라주지 않고,\n마냥 유튜브만 틀어줄 수는 없고...\n함께 노는 것도 고민해야 해?!?\n\n얼굴만 쳐다보고 있어도... '},
#  {'title': '뚝딱뚝딱 입체 종이접기 1 (<b>스프링</b>) (탈것(땅), 큐브)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=19007735',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/190/077/19007735.jpg?type=m1&udate=20210422',
#   'author': '이지숙',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '스쿨존(굿인포메이션)',
#   'pubdate': '20210415',
#   'isbn': '1197415106 9791197415104',
#   'description': '놀이와 두뇌계발, 두 마리 토끼를 동시에!!!\n\n똥손 엄마 도전!\n만들기 잼병 아빠도 함께!\n산만한 우리아이와 함께 할 입체 종이접기!\n\n아이 얼굴만 쳐다보고 있을 수도 없고,\n같이 놀아주려 해도 체력이 따라주지 않고,\n마냥 유튜브만 틀어줄 수는 없고...\n함께 노는 것도 고민해야 해?!?\n\n얼굴만 쳐다보고 있어도... '},
#  {'title': '내손에 헌법 (<b>스프링</b>) (헌법조문집 : 이해를 통한 손에 잡히는 헌법, 제5판)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16365572',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/655/16365572.jpg?type=m1&udate=20200626',
#   'author': '윤우혁',
#   'price': '10000',
#   'discount': '9500',
#   'publisher': '박영사',
#   'pubdate': '20200615',
#   'isbn': '113033659X 9791130336596',
#   'description': '- 독자대상 : 7급 9급 국회직 법원 검찰직 법무사 경찰승진 변호사 5급공채 시험 준비생\n- 구성 및 특징 : 이론'},
#  {'title': '또래 퀴즈 : 호기심 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825226',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825226.jpg?type=m1&udate=20210129',
#   'author': '강영훈 지음|원혜진',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '이젠교육',
#   'pubdate': '20201005',
#   'isbn': '1197068430 9791197068430',
#   'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 호기심 퀴즈 백과≫에는 사람(인체), 동물, 식물, 지구, 자연(환경), 상식 등에 관한 다양하고 재미있는... '},
#  {'title': '시와찬미. 11(<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16419267',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/192/16419267.jpg?type=m1&udate=20200727',
#   'author': 'SFC출판부',
#   'price': '25000',
#   'discount': '22500',
#   'publisher': 'SFC출판부',
#   'pubdate': '20200717',
#   'isbn': '118794243X 9791187942436',
#   'description': '- 시와 찬미 11은 악보집 이용자들이 선호하는 <b>스프링</b> 제본 방식으로 제작되었습니다.\n\n- 시와 찬미11에는 607곡들이 주제별, 코드별로 분류되어 수록되어 있습니다. \n\n- 시와 찬미 11의 주제별 분류는 경배와 찬양, 은혜와 사랑, 회개와 고백, 기도와 간구, 축복과 교제, 선교와 승리로 되어 있습니다.\n- 가사 첫 줄... '},
#  {'title': '하모니카 트로트 콘서트곡집 (<b>스프링</b>) (미스 & 미스터 트롯 히트곡 모음)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17941830',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/179/418/17941830.jpg?type=m1&udate=20210209',
#   'author': '제임스 정',
#   'price': '22000',
#   'discount': '19800',
#   'publisher': '일신서적',
#   'pubdate': '20210310',
#   'isbn': '8936627589 9788936627584',
#   'description': '● 1920년대부터 2020 [미스트롯] ㆍ [미스터트롯]의 인기곡과\n   최신 히트곡을 수록한 하모니카 연주곡집\n\n● 하모니카 숫자악보의 칼라화로 연주에 편리함 \n\n● QR코드를 사용하여 약 80명의 하모니카 연주자의 연주를 \n   유튜브 영상으로 직접 보면서 듣고 즐길 수 있습니다.'},
#  {'title': '<b>스프링</b>북 스도쿠 2 (고급 고수)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13069531',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/130/695/13069531.jpg?type=m1&udate=20200522',
#   'author': '편집부|스도쿠 존 연구소',
#   'price': '7500',
#   'discount': '6750',
#   'publisher': '시간과공간사',
#   'pubdate': '20180108',
#   'isbn': '8971429925 9788971429921',
#   'description': '머리는 쓰면 쓸수록 두뇌가 깨어난다!&#x0D;스마트폰에 익숙한 현대인의 두뇌회전에 도움을!&#x0D;&#x0D;요즘 스마트폰을 사용하지 않는 사람을 보기가 어려울 정도로 우리는 스마트폰 사용률이 높다. 그러다 보니 하루 일과를 스마트폰과 함께 하는 시간이 대부분이다. 오죽하면 스마트폰 제한 앱까지 나왔을까... '},
#  {'title': '초보 웹 개발자를 위한 <b>스프링</b>5 프로그래밍 입문',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=13786861',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/137/868/13786861.jpg?type=m1&udate=20180724',
#   'author': '최범균',
#   'price': '26500',
#   'discount': '23850',
#   'publisher': '가메',
#   'pubdate': '20180720',
#   'isbn': '8980782977 9788980782970',
#   'description': '<b>스프링</b> 프레임워크의 버전업으로 개선된 내용을 담았습니다.\n\n필자의 한마디 : 처음 <b>스프링</b>을 배우고자 하는 독자들이 입문할 때 필요한 것은 <b>스프링</b>의 방대한 내용이 아닌 기초와 전반적인 흐름을 잡아주는 것으로 생각한다.\n\n● <b>스프링</b> DI 기초와 의존 자동 주입\n● <b>스프링</b> AOP 기초\n● <b>스프링</b>을... '},
#  {'title': '수채화 캘리 성경 365 (<b>스프링</b>) (매일 아침 수채화 캘리그라피로 만나는 말씀 묵상)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17652047',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/176/520/17652047.jpg?type=m1&udate=20210119',
#   'author': '김영선|박광철',
#   'price': '13000',
#   'discount': '11700',
#   'publisher': '티나',
#   'pubdate': '20201230',
#   'isbn': '1188417231 9791188417230',
#   'description': '감사와 은혜로 시작하는 매일 아침!\n따뜻한 수채화와 캘리그라피로 만나는 말씀 묵상!『수채화 캘리 성경 365』를 넘기며 감사와 은혜로 하루를 시작해 보자. 감성적인 캘리그라피로 쓰인 성경 구절과 그에 어울리는 정갈한 수채화, 목사님의 성경 말씀 해설을 한 장씩 읽다 보면 은혜가 충만해짐을 느낄 수... '},
#  {'title': '내 인생의 <b>스프링</b> 캠프 (블루픽션 22)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=2954171',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/029/541/02954171.jpg?type=m1&udate=20200305',
#   'author': '정유정',
#   'price': '11000',
#   'discount': '9900',
#   'publisher': '비룡소',
#   'pubdate': '20070701',
#   'isbn': '8949120763 9788949120768',
#   'description': "2007년 제1회 세계청소년문학상 수상작\n\n어느 날 갑자기 낯선 세상으로 뛰어든 열다섯 살 세 애송이들이 펼치는 '개판' 여행. 청룡열차를 탄 것 같은 속도감 있는 문체, 유머 가득 담긴 입담 속에 펼쳐지는 십대들의 풋풋한 사랑과 그 비밀스러운 성장 이야기로, 2007년 제1회 세계청소년문학상 수상작이다.\n\n소설은... "},
#  {'title': '토비의 <b>스프링</b> 3.1 세트 (<b>스프링</b>의 이해와 원리 + <b>스프링</b>의 기술과 선택, 전2권)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=7006516',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/070/065/07006516.jpg?type=m1&udate=20151005',
#   'author': '이일민',
#   'price': '75000',
#   'discount': '67500',
#   'publisher': '에이콘출판',
#   'pubdate': '20120921',
#   'isbn': '8960773433 9788960773431',
#   'description': '『토비의 <b>스프링</b> 3.1』은 <b>스프링</b>을 처음 접하거나 <b>스프링</b>을 경험했지만 <b>스프링</b>이 어렵게 느껴지는 개발자부터 <b>스프링</b>을 활용한 아키텍처를 설계하고 프레임워크를 개발하려고 하는 아키텍트에 이르기까지 모두 참고할 수 있는 <b>스프링</b> 완벽 바이블이다.[Vol. 1 <b>스프링</b>의 이해와 원리] 단순한 예제를... '},
#  {'title': '슬기로운 의사생활 OST 피아노 연주곡집(OST 사운드북 시리즈 1)(<b>스프링</b>) (OST 전곡수록)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16408113',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/081/16408113.jpg?type=m1&udate=20200711',
#   'author': '나정현 (편곡)|정다운 (편곡)|채경원',
#   'price': '12000',
#   'discount': '10800',
#   'publisher': '그래서음악(somusic)',
#   'pubdate': '20200720',
#   'isbn': '1197092501 9791197092503',
#   'description': '모범연주 QR코드, 상세한 코드와 가사가 제공되며 연주할 때 넘기기 쉽게 제작된 <b>스프링</b> 악보로 편리함을 더했습니다. 그 시절 우리가 즐겨듣고 따라 불렀던 추억의 인기가요를 피아노로 연주하며 드라마 속 감동과 여운을 다시 한번 느껴보세요.'},
#  {'title': '어린왕자 탁상달력: 체크 리스트형(2021)(<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17193964',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/171/939/17193964.jpg?type=m1&udate=20201222',
#   'author': '미르북컴퍼니 편집부',
#   'price': '7500',
#   'discount': '4500',
#   'publisher': '미르북컴퍼니(미르북스)',
#   'pubdate': '20201105',
#   'isbn': '9529011725 8809529011724',
#   'description': '『어린왕자 탁상달력: 체크 리스트형(2021)』은 세상에서 가장 순수한 영혼 별처럼 빛나는 어린 왕자와 2021년을 만난다. 앞면에 체크리스트가 있어 매월 중요한 일정을 기입할 수 있다.'},
#  {'title': '배워서 바로 쓰는 <b>스프링</b> 프레임워크 (AOP, 보안, 메시징부터 <b>스프링</b> 웹 MVC까지 실용적인 예제로 한눈에 알아보는 <b>스프링</b> 가이드,Getting started with Spring Framework)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16339880',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/398/16339880.jpg?type=m1&udate=20200601',
#   'author': '애시시 사린,제이 샤르마 공저|오현석',
#   'price': '50000',
#   'discount': '45000',
#   'publisher': '한빛미디어',
#   'pubdate': '20200501',
#   'isbn': '116224304X 9791162243046',
#   'description': '88가지 단계별 프로젝트로 익히는 <b>스프링</b> 프레임워크\n이 책은 <b>스프링</b> 5 기본과 개념, 최신 업데이트된 프레임워크 전반을 단계별로 접근합니다. IoC 컨테이너 같은 <b>스프링</b> 기초부터 <b>스프링</b> 데이터, <b>스프링</b> AOP, <b>스프링</b> 메시징, <b>스프링</b> 웹 MVC, 스트림 API, <b>스프링</b> 시큐리티, RESTful 웹 서비스, 반응형... '},
#  {'title': '또래 퀴즈 : 과학 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825221',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825221.jpg?type=m1&udate=20201028',
#   'author': '강영훈',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '이젠교육',
#   'pubdate': '20201005',
#   'isbn': '1197068422 9791197068423',
#   'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 과학 퀴즈 백과≫에는 과학 현상, 미래과학, 우주, 별과 별자리, 지구와 날씨, 생명과 건강 등에 관한... '},
#  {'title': '기본인체해부학 강의노트 (<b>스프링</b>) (간호·보건대생 실습을 위한)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17895224',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/178/952/17895224.jpg?type=m1&udate=20210223',
#   'author': '김인범',
#   'price': '25000',
#   'discount': '24250',
#   'publisher': '범문에듀케이션',
#   'pubdate': '20210201',
#   'isbn': '1159432325 9791159432323',
#   'description': '『기본인체해부학 강의노트』는 〈뼈대, 관절 및 근육계통〉, 〈순환, 신경 및 피부계통〉, 〈등〉, 〈팔〉, 〈다리〉, 〈얼굴과 목〉 등을 수록하고 있는 책이다.'},
#  {'title': '마블 스튜디오 캡틴 마블 위클리 플래너 (구스 Ver) (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14789245',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/147/892/14789245.jpg?type=m1&udate=20190416',
#   'author': 'Marvel',
#   'price': '8000',
#   'discount': '1900',
#   'publisher': '아르누보',
#   'pubdate': '20190422',
#   'isbn': '9474872821 8809474872821',
#   'description': 'ㆍ들고 다니면서 써도 튼튼한 양장 표지와 넘기기 편한 <b>스프링</b> 제본이 되어 있습니다.\nㆍ일주일의 일정을 한눈에 볼 수 있는 위클리 플래너입니다.\nㆍ앞면 위클리와 뒷면 노트로 반복됩니다. 월과 요일을 자유롭게 쓸 수 있습니다.\n\n당신의 일상의 든든한 파트너가 되어 줄 《캡틴 마블 위클리 플래너-구스 VER.... '},
#  {'title': 'DIAT 프리젠테이션(파워포인트 2010)(발자취)(<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16267940',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/679/16267940.jpg?type=m1&udate=20200229',
#   'author': '수험서개발팀',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '마린북스',
#   'pubdate': '20200210',
#   'isbn': '1190402122 9791190402125',
#   'description': '한국정보통신진흥협회 시행\n국가공인 디지털정보활용능력(DIAT)\n시험 준비에 최적화된 수험서입니다.★ 시험 준비에 필요한 모든 과정을 처음부터 순서대로 구성하여 빈틈없이 시험을 준비할 수 있습니다.\n★ 기능별 학습이 아니라 따라하기식으로 시험 문제를 풀어나가도록 구성하여 쉽게 학습할 수... '},
#  {'title': '낭만의 통기타 고급 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17526327',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/175/263/17526327.jpg?type=m1&udate=20201209',
#   'author': '박해민',
#   'price': '20000',
#   'discount': '18000',
#   'publisher': '민스뮤직출판',
#   'pubdate': '20201126',
#   'isbn': '1195473885 9791195473885',
#   'description': '“낭만의 통기타”는 중장년층이 문화센터나 주민센터, 동호회에서 통기타를 배우기에 적합하게 구성하여 만들어진 교재를 겸한 연주곡집입니다.'},
#  {'title': '또래 퀴즈 : 세계 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825225',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825225.jpg?type=m1&udate=20201028',
#   'author': '최인수 지음|박지원',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '이젠교육',
#   'pubdate': '20201005',
#   'isbn': '1197068406 9791197068409',
#   'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 세계 퀴즈 백과≫에는 세계의 나라, 명소, 문화재, 도시, 음식, 의복, 풍속, 건축에 관한 다양하고 재미있는... '},
#  {'title': '독한국사 독심술 is 100(2)핵심유형 문제집.(최진우)(<b>스프링</b>) (독한국사 심화이론 술술 풀리는 문제 풀이)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16344443',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/444/16344443.jpg?type=m1&udate=20200605',
#   'author': '최진우',
#   'price': '23000',
#   'discount': '20700',
#   'publisher': '더나은',
#   'pubdate': '20200515',
#   'isbn': '1187618624 9791187618621',
#   'description': '- 독자대상 : 공무원 시험 준비생\n- 구성 및 특징 : \n① 최근 경향 반영\n② 학습 내용 체계적으로 구성'},
#  {'title': '로보카폴리 썼다 지웠다 한글 똑똑(<b>스프링</b>) (한글 낱말 195개를 썼다 지웠다!)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16236950',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/369/16236950.jpg?type=m1&udate=20200814',
#   'author': '로이비쥬얼',
#   'price': '12000',
#   'discount': '8400',
#   'publisher': '로이북스',
#   'pubdate': '20200203',
#   'isbn': '9316331382 8809316331387',
#   'description': '<b>스프링</b> 제본으로 책이 쫙 펼쳐져 글씨 쓰기 편하고, 지우개가 달린 자석 보드펜을 책에 쏙 끼워 보관할 수 있어요. 아이 입장에서 생각하며, 꼼꼼하고, 편리하게 만들었답니다. \n초등학교 교과서의 한글 쓰기 획순에 따라 한글 자음과 모음, 다양한 낱말을 고딕체 글씨로 또박또박 따라 쓰기 쉽게 구성했어요.... '},
#  {'title': '또래 퀴즈 : 인물 퀴즈 백과 (<b>스프링</b>) (초등학생을 위한 지식 퀴즈 백과)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16825224',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/168/252/16825224.jpg?type=m1&udate=20201028',
#   'author': '최인수',
#   'price': '10000',
#   'discount': '9000',
#   'publisher': '이젠교육',
#   'pubdate': '20201005',
#   'isbn': '1197068414 9791197068416',
#   'description': '서로 묻고 답하며 두뇌&지식이 쑥쑥 커져요!!\n≪초등학생을 위한 지식 퀴즈 백과 또래 퀴즈 시리즈≫는 초등학생이 알아야 하는 지식을 퀴즈 형식으로 담아낸 지식 퀴즈 백과입니다. 이 책 ≪또래 퀴즈 - 인물 퀴즈 백과≫에는 인물과 관련한 장소, 역사, 과학, 예술, 사회, 문화, 나라 등에 관한 다양하고... '},
#  {'title': '<b>스프링</b> 입문을 위한 자바 객체 지향의 원리와 이해',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=8920762',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/089/207/08920762.jpg?type=m1&udate=20170602',
#   'author': '김종민',
#   'price': '25000',
#   'discount': '22500',
#   'publisher': '위키북스',
#   'pubdate': '20150408',
#   'isbn': '8998139944 9788998139940',
#   'description': '이 책은 자바에서 <b>스프링</b>으로 나아가기 위한 연결 고리를 제공한다.'},
#  {'title': '마이 로맨틱 유럽 스티커 컬러링북 + 마이 스위트 카페 스티커 컬러링북 - 전2권 (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16388821',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/888/16388821.jpg?type=m1&udate=20200729',
#   'author': '이수현',
#   'price': '24000',
#   'discount': '10000',
#   'publisher': '아르누보',
#   'pubdate': '20200622',
#   'isbn': '947487557X 8809474875570',
#   'description': '당신이 꿈꾸는 달콤한 쉼터는 어떤 색인가요?\n감성을 담은 컬러링 스티커에 나만의 색을 입혀 보세요.감미로운 커피 향기를 따라가면 발견할 수 있는 나만의 스위트 카페! 당신에게 달콤한 쉼터가 되어줄 멋진 카페들과 그곳에서 맛볼 수 있는 고소한 빵, 상큼한 샐러드, 달달한 케이크와 쌉쌀한 커피, 살살 녹는... '},
#  {'title': 'AKMU 악동뮤지션 피아노 연주곡집(내가 좋아하는 스타)(<b>스프링</b>) (내가 좋아하는 스타)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16744299',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/167/442/16744299.jpg?type=m1&udate=20200922',
#   'author': '김지은',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '태림스코어',
#   'pubdate': '20200930',
#   'isbn': '115780294X 9791157802944',
#   'description': '대한민국을 대표하는 남매 혼성 듀오 AKMU(악동뮤지션)!\n이 책은 음원 강자 AKMU(악동뮤지션)의 인기곡을 엄선하여 엮은 피아노 연주곡집입니다. \n일상 속의 여러 순간들을 다양한 시각과 감성으로 녹여낸 그들의 음악을 피아노로 연주할 수 있도록 체르니 30번 수준으로 편곡하여 원곡의 길이와 매력을 그대로... '},
#  {'title': 'DIAT 워드프로세서(한글 2010)(발자취)(<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16267943',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/679/16267943.jpg?type=m1&udate=20200229',
#   'author': '수험서개발팀',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '마린북스',
#   'pubdate': '20200210',
#   'isbn': '1190402130 9791190402132',
#   'description': '한국정보통신진흥협회 시행\n국가공인 디지털정보활용능력(DIAT)\n시험 준비에 최적화된 수험서입니다.★ 시험 준비에 필요한 모든 과정을 처음부터 순서대로 구성하여 빈틈없이 시험을 준비할 수 있습니다.\n★ 기능별 학습이 아니라 따라하기식으로 시험 문제를 풀어나가도록 구성하여 쉽게 학습할 수... '},
#  {'title': '이정환의 파퓰러 & 뉴에이지 컬렉션 1 (<b>스프링</b>) (개정판)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17468982',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/174/689/17468982.jpg?type=m1&udate=20201120',
#   'author': '이정환',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '음악세계',
#   'pubdate': '20201115',
#   'isbn': '8966855555 9788966855551',
#   'description': '『이정환의 파퓰러 & 뉴에이지 컬렉션(개정판)』은 막상 연주하려고 하면 너무 어렵거나, 악보는 쉽지만 단순해 곡의 묘미를 살리지 못하는 문제점을 해결할 수 있는 연주곡집으로 뉴에이지, 팝송, 샹송, 영화음악, 클래식, 가요 등 다양한 장르의 음악을 멋지고 맛깔스럽게 연주할 수 있도록 편곡하였으며... '},
#  {'title': '영문 필기체 노트 바르다 <b>스프링</b>북 (영어에 멋을 더해주는 캘리 기초용 손글씨 교본)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=12472137',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/124/721/12472137.jpg?type=m1&udate=20170824',
#   'author': '편집부',
#   'price': '13000',
#   'discount': '6500',
#   'publisher': '42미디어콘텐츠',
#   'pubdate': '20170904',
#   'isbn': '9482280288 8809482280281',
#   'description': '베스트셀러 [영문 필기체 노트 바르다]를 실용적인 <b>스프링</b>북으로 리뉴얼해 더욱 편리해진 [영문 필기체 노트 바르다 <b>스프링</b>북]으로 매일 꾸준히 영문... 활용할 수 있는 예쁜 영문 필기체를 완성할 수 있습니다. [영문 필기체 노트 바르다 <b>스프링</b>북]과 함께 나만의 멋진 영문 필기체를 마음껏 뽐내 보세요!'},
#  {'title': '색소폰 연주곡 따라하기(임희승의)(나고수 색소폰 시리즈)(<b>스프링</b>) (동영상, 사전 연습, 실전 악보)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16315127',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/151/16315127.jpg?type=m1&udate=20200630',
#   'author': '임희승',
#   'price': '20000',
#   'discount': '18000',
#   'publisher': '세광음악출판사',
#   'pubdate': '20200327',
#   'isbn': '8903435176 9788903435174',
#   'description': '시대에 맞는 색소폰 교본의 새로운 해법을 내놓았던 『나고수 색소폰 초급편』,  『나고수 색소폰 중·고급편』, 『쉽게 배우는 색소폰 애드리브』에 이어 이번엔 ‘YOUTUBE’라는 새로운 플랫폼과 함께 돌아온 『임희승의 색소폰 연주곡 따라하기』. 악보 중심의 교재들과 달리  ‘이론 편, 연주곡 편(중급... '},
#  {'title': '라바 어린이 스도쿠 <b>스프링</b>북 초급 중급 (두뇌 계발 × 사고력 UP)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16687985',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/166/879/16687985.jpg?type=m1&udate=20200917',
#   'author': '슈퍼스도쿠퍼즐연구소',
#   'price': '7500',
#   'discount': '6750',
#   'publisher': '바이킹',
#   'pubdate': '20201005',
#   'isbn': '8964944607 9788964944608',
#   'description': '스도쿠를 매일 풀다 보면 두뇌 계발은 물론 숫자에 흥미를 느끼고 수학이 재밌어질 것이다. 문제에 도전하고 해결하는 즐거움도 느낄 수 있다. &lt;라바 어린이 스도쿠 <b>스프링</b>북 초급&gt;, &lt;라바 어린이 스도쿠 <b>스프링</b>북 초급 중급&gt;을 만나 보자.'},
#  {'title': '<b>스프링</b> 마이크로서비스 코딩 공작소 (Spring Microservices in Action)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14371209',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/143/712/14371209.jpg?type=m1&udate=20190204',
#   'author': '존 카넬',
#   'price': '33000',
#   'discount': '29700',
#   'publisher': '길벗',
#   'pubdate': '20181221',
#   'isbn': '1160506817 9791160506815',
#   'description': '&#x0D;<b>스프링</b> 부트 2와 <b>스프링</b> 클라우드 2로 구현하며 배우는 컨테이너 기반의 마이크로서비스 &#x0D;&#x0D;마이크로서비스에서는 배포가 중요한 이슈다. <b>스프링</b> 클라우드를 사용하면 마이크로서비스의 빌드와 배포를 최소화할 수 있고, 이런 의미에서 <b>스프링</b> 부트와 <b>스프링</b> 클라우드의 조합은 매력적이다. 20년간... '},
#  {'title': '하루를 시작하는 한 줄 가톨릭 (<b>스프링</b>) (YOUCAT CALENDAR)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17727034',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/177/270/17727034.jpg?type=m1&udate=20210107',
#   'author': 'YOUCAT 재단 지음|김선태 외',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '가톨릭출판사',
#   'pubdate': '20210131',
#   'isbn': '8932117543 9788932117546',
#   'description': '하루에 하나씩 교리를 익힌다!\n처음으로 선보이는 365일 만년 교리 달력많은 신자들에게 대표적인 교리서로 자리 잡은 YOUCAT 시리즈 중 《YOUCAT》, 《YOUCAT 프렌즈》, 《DOCAT》에서 핵심적인 교리 내용을 모은 365일 만년 달력이다. 언택트 시대에 맞춰 장소에 구애받지 않고 교리를 매일 하나씩 익힐 수... '},
#  {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea A형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 박재범)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062657',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062657.jpg?type=m1&udate=20210306',
#   'author': '렉스트림 편집부',
#   'price': '9000',
#   'discount': '',
#   'publisher': '렉스트림',
#   'pubdate': '20210309',
#   'isbn': '7826745004 2597826745003',
#   'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#  {'title': 'ITQ 파워포인트 2010(2020)(이공자)(개정판)(<b>스프링</b>) (최신 자동채점프로그램 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16265070',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/650/16265070.jpg?type=m1&udate=20200226',
#   'author': 'KIE 기획연구실',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '아카데미소프트',
#   'pubdate': '20200214',
#   'isbn': '8984557676 9788984557673',
#   'description': '- 2020년 7월 정기시험부터 새롭게 변경된 시험유형을 모두 반영한 최신교재!!\n- 기출 예상문제 완벽대비!!\n- 최신 자동채점프로그램 무료 제공!!'},
#  {'title': 'ITQ 엑셀 ver.2010(이기적)(<b>스프링</b>) (최신 출제기준 분석 + 동영상 강의 무료 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16430051',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/300/16430051.jpg?type=m1&udate=20200729',
#   'author': '영진정보연구소',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '영진닷컴',
#   'pubdate': '20200720',
#   'isbn': '8931463111 9788931463118',
#   'description': '본 도서는 ITQ 엑셀 시험 경향을 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서입니다. 엑셀 VER.2010을 기준으로 작성되었으며, 2020년 7월 공식 시험버전이 2016으로 변경되었지만 2021년까지 2010버전도 응시가 가능하므로 상황에 맞게 선택하실 수 있습니다.\n꼼꼼이론과 유형을 확인하는... '},
#  {'title': 'ITQ 한쇼 2016(2020)(이공자)(<b>스프링</b>) (새롭게 변경된 시험유형을 모두 반영)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16292299',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/922/16292299.jpg?type=m1&udate=20201118',
#   'author': 'KIE기획연구실',
#   'price': '16000',
#   'discount': '14400',
#   'publisher': '아카데미소프트',
#   'pubdate': '20200316',
#   'isbn': '8984550051 9788984550056',
#   'description': '- 2020년 7월 정기시험부터 새롭게 변경된 시험유형을 모두 반영한 최신교재!!\n- 기출 예상문제 완벽대비!!\n\n● 내용설명\n● 출제유형 완전정복 \n최근에 출제된 ITQ 시험의 출제유형을 분석하여 새롭게 변경된 내용과 시험에 자주 출제되는 부분을 단계별로 체크하고 작성할 수 있도록 구성하였습니다.... '},
#  {'title': 'ITQ 파워포인트 ver.2010(이기적)(<b>스프링</b>) (최신 출제기준 분석 + 동영상 강의 무료 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16430061',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/300/16430061.jpg?type=m1&udate=20200728',
#   'author': '영진정보연구소',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '영진닷컴',
#   'pubdate': '20200720',
#   'isbn': '893146312X 9788931463125',
#   'description': '본 도서는 ITQ 파워포인트 시험 경향을 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서입니다. 파워포인트 VER.2010을 기준으로 작성되었으며, 2020년 7월 공식 시험버전이 2016으로 변경되었지만 2021년까지 2010버전도 응시가 가능하므로 상황에 맞게 선택하실 수 있습니다.\n꼼꼼한 이론과... '},
#  {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea B형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 그루비룸)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062658',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062658.jpg?type=m1&udate=20210306',
#   'author': '렉스트림 편집부',
#   'price': '9000',
#   'discount': '',
#   'publisher': '렉스트림',
#   'pubdate': '20210309',
#   'isbn': '7826758009 2597826758003',
#   'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#  {'title': '마블 스튜디오 캡틴 마블 위클리 플래너 (캡틴마블 Ver) (<b>스프링</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=14789244',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/147/892/14789244.jpg?type=m1&udate=20190416',
#   'author': 'Marvel',
#   'price': '8000',
#   'discount': '1900',
#   'publisher': '아르누보',
#   'pubdate': '20190422',
#   'isbn': '9474872813 8809474872814',
#   'description': 'ㆍ들고 다니면서 써도 튼튼한 양장 표지와 넘기기 편한 <b>스프링</b> 제본이 되어 있습니다.\nㆍ일주일의 일정을 한눈에 볼 수 있는 위클리 플래너입니다.\nㆍ앞면 위클리와 뒷면 노트로 반복됩니다. 월과 요일을 자유롭게 쓸 수 있습니다.\n\n당신의 일상의 든든한 파트너가 되어 줄 《캡틴 마블 위클리 플래너》와 함꼐... '},
#  {'title': 'ACL 김중근 형법 Sub Note (4판 1쇄, <b>스프링</b>) (경찰채용, 경찰간부, 경찰승진, 법원직, 검찰직 , 해경, 해경간부)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16274209',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/162/742/16274209.jpg?type=m1&udate=20210318',
#   'author': '김중근',
#   'price': '14000',
#   'discount': '12600',
#   'publisher': '에이씨엘커뮤니케이션',
#   'pubdate': '20200220',
#   'isbn': '1165230267 9791165230265',
#   'description': '- 독자대상 : 경찰채용 경찰간부 경찰승진 법원직 검찰직 해경 해경간부 시험 준비생\n- 구성 : 이론 + 문제\n- 특징 : \n① 판서 내용 정리 \n② 알아보기 쉽고 깔끔한 필기체 반영 \n③ 오답률 높은 지문을 OX 문제로 수록'},
#  {'title': '해피 스텔라 한글 숫자 알파벳 썼다 지웠다(<b>스프링</b>) (썼다 지웠다)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16405444',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/054/16405444.jpg?type=m1&udate=20200807',
#   'author': '로이비쥬얼',
#   'price': '12000',
#   'discount': '8400',
#   'publisher': '로이북스',
#   'pubdate': '20200701',
#   'isbn': '9316331447 8809316331448',
#   'description': '<b>스프링</b> 제본으로 책이 쫙 펼쳐져 글씨 쓰기 편하고, 지우개가 달린 자석 보드펜을 책에 쏙 끼워 보관할 수 있지요. 아이 입장에서 생각하며, 꼼꼼하고, 편리하게 만들었답니다.\n\n초등학교 교과서 쓰기 획순에 따라 한글과 숫자를, 영미권 쓰기 책과 교과서 쓰기 순서에 따라 알파벳을 또박또박 따라 쓰기 쉽게... '},
#  {'title': '예제로 배우는 <b>스프링</b> 부트 입문 (JSP, Oracle, MyBatis와 연동한 웹 애플리케이션 만들기)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17523749',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/175/237/17523749.jpg?type=m1&udate=20201203',
#   'author': '이재환',
#   'price': '30000',
#   'discount': '27000',
#   'publisher': '비제이퍼블릭',
#   'pubdate': '20201130',
#   'isbn': '1165920301 9791165920302',
#   'description': '<b>스프링</b> 부트의 이론부터 실전까지\n예제로 가장 쉽고 빠르게, 체계적으로 배운다!기존의 책들은 이론이 너무 많았습니다. 그래서 <b>스프링</b>을 대하는 학생들을 보면 일단 너무 어려워하거나 지루해했습니다.... 이 책에서는 <b>스프링</b> 부트에 필요한 이론은 놓치지 않고 자연스럽게 모두 익힐 수 있도록 구성하였습니다.... '},
#  {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea C형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 이승찬)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062659',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062659.jpg?type=m1&udate=20210306',
#   'author': '렉스트림 편집부',
#   'price': '9000',
#   'discount': '',
#   'publisher': '렉스트림',
#   'pubdate': '20210309',
#   'isbn': '7826769000 2597826769009',
#   'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#  {'title': '데이즈드 앤 컨퓨즈드 코리아 Dazed & Confused Korea D형 (월간) : <b>스프링</b> 에디션 [2021] (표지 : 초록)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18062660',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/180/626/18062660.jpg?type=m1&udate=20210306',
#   'author': '렉스트림 편집부',
#   'price': '9000',
#   'discount': '',
#   'publisher': '렉스트림',
#   'pubdate': '20210309',
#   'isbn': '782679000X 2597826790003',
#   'description': '데이즈드 <b>스프링</b> 에디션&#x0D;박재범, 그루비룸, 재미나이, 헤론 프레스톤과의 교점/나나와 이민기/미래소년 첫 출격'},
#  {'title': '실전 <b>스프링</b> 부트 REST API 개발 MyBatis + MySQL 개정판',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=18896291',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/188/962/18896291.jpg?type=m1&udate=20210406',
#   'author': '향단코드',
#   'price': '10000',
#   'discount': '',
#   'publisher': '온노트',
#   'pubdate': '20210406',
#   'isbn': '1190230194 9791190230193',
#   'description': '이 책은 <b>스프링</b> 부트를 이용하여 REST API 시스템을 개발하고자 하는 사람을 위한 것입니다.\n이미지를 판매하는 간단한 디지털 컨텐츠 샵의  REST API를 구축해 봄으로써 Restful 서비스를 위한 <b>스프링</b> 부트의 실제 사용법을 배울 수 있습니다.\n실전 프로젝트 개발에 필요한 Restful 서비스와 <b>스프링</b> 부트의... '},
#  {'title': '박물관 전시기획 마스터하기 (<b>스프링</b>) (전시 개발의 전략)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16418031',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/180/16418031.jpg?type=m1&udate=20200717',
#   'author': '더크 휴트그라프',
#   'price': '12000',
#   'discount': '10800',
#   'publisher': 'TSCP(더쉐이크크리에이티브)',
#   'pubdate': '20200715',
#   'isbn': '1195278942 9791195278947',
#   'description': '한권으로 충분하다! 전시기획 마스터 하기!“오늘날 대부분의 박물관들은 자신들이 더 이상 유물 또는 표본 중심의 기관이 아니라고 인식하고 있다.\n박물관이 아이디어, 경험, 내러티브 중심의 기관이어야 한다는 것이다.”\n\n“박물관의 메시지나 의도를 시각적, 공간적 언어로 해석하여 관람객이 참여하게 하고... '},
#  {'title': '실전! <b>스프링</b> 5를 활용한 리액티브 프로그래밍 (리액티브 애플리케이션 개발부터 클라우드 배포와 모니터링까지)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15045543',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/150/455/15045543.jpg?type=m1&udate=20190613',
#   'author': '올레 도쿠카|이호르 로진스키',
#   'price': '32000',
#   'discount': '28800',
#   'publisher': '위키북스',
#   'pubdate': '20190621',
#   'isbn': '1158391595 9791158391591',
#   'description': '리액티브 시스템을 탐험하고 <b>스프링</b> 부트와 <b>스프링</b> 클라우드를 사용해 효율적인 마이크로 서비스를 만들어 보자!오늘날 기업은 어떤 상황에도 높은... <b>스프링</b> 프레임워크 개발자들은 응답성 높은 시스템을 만들기 위해 리액터 프로젝트를 제안하고 출시했습니다.\n\n이 책은 <b>스프링</b>을 이용한 리액티브... '},
#  {'title': '플루트, 시작해볼까? 1 (<b>스프링</b>) (나의 첫 번째 플루트 교본)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17526668',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/175/266/17526668.jpg?type=m1&udate=20201128',
#   'author': '송화진',
#   'price': '13000',
#   'discount': '11700',
#   'publisher': '음악세계',
#   'pubdate': '20201130',
#   'isbn': '8966855598 9788966855599',
#   'description': '초급과정으로 아이부터 성인까지 플루트를 쉽게 배울 수 있고, 방과 후 교실이나 개인·그룹 레슨, 학원 등에서 활용할 수 있습니다. 배운 것을 바로 적용할 수 있는 다양한 예제곡과 시대 흐름에 맞는 실용적인 실전 연주곡 102곡을 수록하였습니다. 또한, 2·3 파트 음원 QR코드를 수록하여 혼자서도 이... '}]

# %%
result['items'][0]
# Out:
# {'title': '올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)',
#  'link': 'http://book.naver.com/bookdb/book_detail.php?bid=17193966',
#  'image': 'https://bookthumb-phinf.pstatic.net/cover/171/939/17193966.jpg?type=m1&udate=20210324',
#  'author': '올리버 샨 그랜트',
#  'price': '18500',
#  'discount': '16650',
#  'publisher': '비에이블',
#  'pubdate': '20201119',
#  'isbn': '1190931184 9791190931182',
#  'description': '하루 3분, 미국인 선생님과 함께하는 매일 영어 습관\n“원어민 발음에 귀가 열리고, 요즘 영어로 더 유창하게 말하게 된다!”\n외국어 분야 베스트셀러 저자인 올리버쌤이 하루 한 문장씩 1년간 365개 표현을 익힐 수 있는 영어회화 일력을 출간했다. 미국인이 아니면 가르쳐줄 수 없는 원어민들의 생활 속 표현을... '}

# %%
result['items'][0]['title']
# Out:
# '올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)'

# %%
#for문 이용해서 title을 가지고 올 것.
titles = [result['items'][n]['title'] for n in range(3)]
titles
# Out:
# ['올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)',
#  '구슬쥬의 시크릿 내신노트 (<b>스프링</b>)',
#  '2021 전한길 한국사 포켓 암기노트 (<b>스프링</b>) (공무원 시험 대비)']

# %%
pubdates = [result['items'][n]['pubdate'] for n in range(3)]
pubdates
# Out:
# ['20201119', '20210228', '20201010']

# %%
authors = [result['items'][n]['author'] for n in range(3)]
authors
# Out:
# ['올리버 샨 그랜트', '구슬쥬', '전한길']

# %%
type(authors)
# Out:
# list

# %%
import pandas as pd

# %%
pd.DataFrame({'책제목':titles, '작가':authors, '출판일':pubdates})
# Out:
#                                                  책제목         작가       출판일
# 0  올리버쌤의 영어회화 일력 365(<b>스프링</b>) (하루 한 문장 미국식 영어 습관)  올리버 샨 그랜트  20201119
# 1                         구슬쥬의 시크릿 내신노트 (<b>스프링</b>)        구슬쥬  20210228
# 2      2021 전한길 한국사 포켓 암기노트 (<b>스프링</b>) (공무원 시험 대비)        전한길  20201010

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
def get_dataframe(url):
    client_id ="sOiJUp7sd7dBiZpgADzZ"
    client_secret = "xSmJkjTmIU"

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)

    response = urllib.request.urlopen(request)
    content = response.read().decode('utf-8')
    
    result = json.loads(content)
    end_num = result['display']
    
    titles = [delete_tag(result['items'][n]['title']) for n in range(end_num)]
    pubdates = [result['items'][n]['pubdate'] for n in range(end_num)]
    authors = [result['items'][n]['author'] for n in range(end_num)]
    
    return pd.DataFrame({'책제목':titles, '작가':authors, '출판일':pubdates})

# %%
url = create_url("book", "스프링", 1,3)
get_dataframe(url)
# Out:
#                                           책제목         작가       출판일
# 0  올리버쌤의 영어회화 일력 365(스프링) (하루 한 문장 미국식 영어 습관)  올리버 샨 그랜트  20201119
# 1                         구슬쥬의 시크릿 내신노트 (스프링)        구슬쥬  20210228
# 2      2021 전한길 한국사 포켓 암기노트 (스프링) (공무원 시험 대비)        전한길  20201010

# %%
[n for n in range(1,300, 100)]
# Out:
# [1, 101, 201]

# %%
result_search = []

for n in range(1, 300, 100):
    url = create_url("book", "스프링", n, 100)
    result_search.append(get_dataframe(url))

result_search = pd.concat(result_search)
result_search
# Out:
#                                                   책제목          작가       출판일
# 0          올리버쌤의 영어회화 일력 365(스프링) (하루 한 문장 미국식 영어 습관)   올리버 샨 그랜트  20201119
# 1                                 구슬쥬의 시크릿 내신노트 (스프링)         구슬쥬  20210228
# 2              2021 전한길 한국사 포켓 암기노트 (스프링) (공무원 시험 대비)         전한길  20201010
# 3        하루 한 장 365 인문학 달력 (스프링) (매일 한 뼘씩 아이 마음이 자라는)         김종원  20201209
# 4   2021 에듀윌 공인중개사 부동산세법 체계도 (스프링) (빠른 합격을 위한 세법 압...         신성룡  20210201
# ..                                                ...         ...       ...
# 95  2017 페인팅레이디 열여덟번째 동화달력 - 나와 아이들(스프링) (책상위의 작은 ...         김계희  20161118
# 96                         [코랄] 인디고 프리즘 스프링노트 192 미디움  인디고(주) 편집부  20200206
# 97                  실전 스프링 부트 REST API 개발 JPA + MySQL        향단코드  20200427
# 98                         [블랙] 인디고 프리즘 스프링노트 192 미디움  인디고(주) 편집부  20200206
# 99                                물고기가 인사해요. 멍멍 (스프링)     스티브 젠킨스  20081201
#
# [300 rows x 3 columns]

# %%
result_search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   책제목     300 non-null    object
#  1   작가      300 non-null    object
#  2   출판일     300 non-null    object
# dtypes: object(3)
# memory usage: 9.4+ KB

# %%
result_search = result_search.reset_index(drop=True)
result_search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   책제목     300 non-null    object
#  1   작가      300 non-null    object
#  2   출판일     300 non-null    object
# dtypes: object(3)
# memory usage: 7.2+ KB

# %%
result_search.to_excel('data/naver_api_result.xlsx')

# %%
# 영화 movie.json => 영화에 대한 정보
# 쇼핑 shop.json => 쇼핑에 대한 정보

# 네이버

# id:sOiJUp7sd7dBiZpgADzZ

# secret:xSmJkjTmIU

# titles = title 리스트를 가지고 올 것.
# pubdates = pubdate 리스트 가지고 올 것.
# authors = author 리스트를 가지고올 것.
